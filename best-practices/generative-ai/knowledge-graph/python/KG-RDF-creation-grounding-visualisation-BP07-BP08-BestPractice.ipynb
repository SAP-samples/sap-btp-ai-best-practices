# %% [markdown]
# # Knowledge Graph Grounding for LLMs in SAP Ecosystem
#
# The *Knowledge Graph Grounding for LLMs* initiative showcases the application of Retrieval-Augmented Generation (RAG) in integrating a Language Model (LLM) with data structured within a Knowledge Graph. This solution encapsulates the entire process, from constructing the Knowledge Graph (KG) from unstructured raw text to building a functional Chat application that can query and interact with this knowledge base.
#
# As part of this R&D project, the following objectives are targeted:
#
# 1. **Evaluate LangChain Tools for Knowledge Graph Integration:** - Assess the LangChain ecosystem and its ability to handle interactions with Knowledge Graphs effectively. Specifically, this involves exploring LangChains tools to integrate various data sources, including enterprise-specific databases, into an LLM model.
#
# 2. **LLM-Assisted Knowledge Graph Construction:** - Investigate the feasibility of leveraging LLMs to automate the construction of Knowledge Graphs directly from raw text data. This includes exploring techniques for extracting entities, relationships, and attributes from structured and unstructured data sources, and how LLMs can assist in enhancing the accuracy and automation of this process.
#
# 3. **Evaluate Triplestore (RDF Store) in HANA Cloud:** - Conduct a hands-on evaluation of working with SAPs HANA Cloud triplestore, an RDF store, which is in Beta at the time of writing. The focus will be on assessing its developer experience, performance, and integration with SAPs broader ecosystem, especially its compatibility with other enterprise systems for managing semantic data.
#
# ### Potential Use Cases in SAP:
#
# - **Enterprise Data Integration:** - By grounding LLMs with a Knowledge Graph, SAP systems can significantly enhance data integration and retrieval processes across multiple sources, improving the accuracy and speed of decision-making. This approach can be applied in areas such as finance, procurement, or customer relationship management (CRM).
#
# - **Intelligent Chatbots for Enterprise Applications:** - The constructed Knowledge Graph can be used to power intelligent chatbots integrated into SAP S4HANA or SAP Fiori applications. These chatbots could assist employees with querying operational data, guiding them through business processes, or providing data-driven insights.
#
# - **Automated Data Modeling:** - Using LLMs to assist in the automated creation of Knowledge Graphs from raw text could significantly reduce the time and effort required for data modeling, particularly in complex enterprise systems where textual data is abundant (e.g., contracts, specifications, manuals).
#
# - **Enhanced Business Intelligence (BI):** - Grounding LLMs with structured data stored in a Knowledge Graph can facilitate advanced business intelligence applications. By querying the KG for insights, users can gain a deeper understanding of trends, performance, and operational bottlenecks in real-time.
#
# - **Semantic Search in SAP Solutions:** - Knowledge Graph grounding could enable more advanced semantic search capabilities in SAP solutions, allowing users to query data using natural language and retrieve contextually relevant results rather than relying on traditional keyword-based searches.
#
# **Data sample:**
#
# - https://www.ebmud.com/application/files/3416/7771/2399/2312_-_Four_1500-HP_Main_Air_Compressor_Motors_FINAL.pdf
# - https://docs.rs-online.com/d853/A700000006779737.pdf
# - https://docs.rs-online.com/aee6/A700000008070326.pdf
#
# but you can use your own data in pdf format.
#
#
# This integration of LLMs with SAP Knowledge Graphs has the potential to transform how organizations manage, retrieve, and utilize enterprise data, particularly in environments that rely heavily on large volumes of unstructured or semi-structured data.
#
# The results of your run may differ from the results in this notebook. Try, improve!

# %% [markdown]
# ![image.png](attachment:ca3d4b49-8ed1-43e6-ae18-ae906671ce91.png)
#
# #### **Important Setup:**  .env File Required for AI CORE Access
#
# Before running the application, ensure that the `.env` file is present in the same directory as the source code. This file contains the necessary credentials for accessing AI CORE.
#
# The `.env` file should include the following lines with the appropriate values:
#
# > AICORE_AUTH_URL="https://*xxxxxxx.authentication.eu10.hana.ondemand.com"
# > AICORE_CLIENT_ID= "xxxxxxxx"
# > AICORE_CLIENT_SECRET="xxxxx"
# > AICORE_BASE_URL="https://api.xxxxxxxx.hana.ondemand.com/v2"
# > AICORE_RESOURCE_GROUP="default"
#
#
# **Make sure to replace the placeholders (`xxxxxxx`) with your actual AI CORE credentials.**

# %% [markdown]
# Environment Setup
# This  block handles the setup of the environment.
# It loads necessary credentials and configurations from a .env file.
# Ensure your .env file includes AICORE access details before proceeding.

# %%
from pathlib import Path
import sys
from dotenv import load_dotenv

# repo_root = next(
#     parent for parent in (Path.cwd(), *Path.cwd().parents)
#     if (parent / ".git").exists()
# )
# dotenv_path = repo_root / "best-practices/generative-ai/knowledge-graph/python/.env"
# notebook_directory = dotenv_path.parent
# if str(notebook_directory) not in sys.path:
#     sys.path.insert(0, str(notebook_directory))

# assert dotenv_path.is_file(), f"Missing .env file: {dotenv_path}"
load_dotenv()

# print(f"Loaded environment from: {dotenv_path}")
# Out:
# True

# %%
# Install necessary packages (langchain, rdflib, networkx, matplotlib etc.)
import os
import re
from gen_ai_hub.proxy.langchain.openai import ChatOpenAI
from gen_ai_hub.proxy.core.proxy_clients import get_proxy_client


# Create a proxy client for the AI Hub
proxy_client = get_proxy_client('gen-ai-hub')
chat_llm = ChatOpenAI(proxy_model_name='gpt-4.1', proxy_client=proxy_client, temperature=0.0)

# %% [markdown]
# ## Data Ingestion
# Import raw data from the source. Build the Knowledge Graph using a Language Model (LLM)

# %%
from langchain_community.graphs.index_creator import GraphIndexCreator
from langchain_community.document_loaders import PyPDFLoader
from prompts import KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT

loader = PyPDFLoader("2312_-_Four_1500-HP_Main_Air_Compressor_Motors_FINAL.pdf")
docs = loader.load()
doc_content = 'This is a compressor specification: '
for doc in docs:
    doc_content = doc_content + ' ' + doc.page_content

index_creator = GraphIndexCreator(llm=chat_llm)

graph = index_creator.from_text(text=doc_content, prompt=KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT)

# %% [markdown]
# ## Extracted Triples

# %% [markdown]
#  **Objective:** Extract knowledge triples (subject-predicate-object) from the given text.
#
#  **Method:** Use a pre-defined prompt and the OpenAI API to instruct the LLM to extract triples.

# %%
triples  = graph.get_triples()
print(triples)
# Out:
# [('1500-HP Main Air Compressor Motor', 'Equipment', 'is a'), ('1500-HP Main Air Compressor Motor', '1500 HP', 'has power rating'), ('1500-HP Main Air Compressor Motor', '4160V', 'operates at voltage'), ('1500-HP Main Air Compressor Motor', '60Hz', 'operates at frequency'), ('1500-HP Main Air Compressor Motor', '3600 RPM', 'has speed rating'), ('1500-HP Main Air Compressor Motor', '95% or higher at 100% load', 'has efficiency rating'), ('1500-HP Main Air Compressor Motor', 'power factor 0.936 or higher', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'full load current 180A', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'locked rotor current 6.3 or less x FLA', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'locked rotor KVA code G', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'service factor 1.15 @ 105°C', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'ambient temperature 40°C max / 0°C min', 'has temperature rating'), ('1500-HP Main Air Compressor Motor', 'Class B temperature rise', 'has temperature rating'), ('1500-HP Main Air Compressor Motor', 'Class F insulation', 'has insulation class'), ('1500-HP Main Air Compressor Motor', 'NEMA WP I enclosure', 'has protection rating'), ('1500-HP Main Air Compressor Motor', 'Weather-Protected I (WP-I)', 'has protection rating'), ('1500-HP Main Air Compressor Motor', 'IP rating per NEMA MG-1.25', 'has protection rating'), ('1500-HP Main Air Compressor Motor', 'RTDs for winding temperature detection', 'is equipped with'), ('1500-HP Main Air Compressor Motor', 'RTDs for bearing temperature detection', 'is equipped with'), ('1500-HP Main Air Compressor Motor', 'vibration sensors', 'is equipped with'), ('1500-HP Main Air Compressor Motor', 'space heaters 240V 1 phase 400W', 'is equipped with'), ('1500-HP Main Air Compressor Motor', 'main and auxiliary terminal boxes', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'copper or copper alloy rotor bars and end rings', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'stator core built from low loss high permeability steel laminations', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'Babbitted sleeve bearings with splash lubrication', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'stainless steel screens and air filters', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'removable filter housing', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'dynamic balancing per NEMA MG 1 Part 7', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'sound level 85 dB(A) at 3 feet at no-load', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'minimum locked rotor torque 2150 ft-lb', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'rated torque at design speed 2188 ft-lb', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'minimum breakaway torque at 2413V 600 ft-lb', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'driven load inertia (WR2) at start 520 lb-ft2', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'vibration not to exceed 0.10 in/sec peak', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'maximum temperature rise 80°C @ 1.0 SF and 90°C @ 1.15 SF', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'stainless steel nameplate per NEMA MG 1-20.60', 'has protection rating'), ('1500-HP Main Air Compressor Motor', 'severe duty marine grade ANSI 61 gray paint finish', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'API 541', 'has industry standard'), ('1500-HP Main Air Compressor Motor', 'NEMA MG 1', 'has industry standard'), ('1500-HP Main Air Compressor Motor', 'ANSI', 'has industry standard'), ('1500-HP Main Air Compressor Motor', 'IEEE 43', 'has industry standard'), ('1500-HP Main Air Compressor Motor', 'IEEE 85', 'has industry standard'), ('1500 ...

# %%
triples[0][0]
# Out:
# '1500-HP Main Air Compressor Motor'

# %% [markdown]
# ## KG - Simple Visualization
# from langchain.indexes.graph - sometimes ready-made and quick visualizations don't look very nice
#
# ### Graphviz Installation Instructions
# For the following code to work and plot the graphs, you need to install Graphviz.
#
# macOS (using Homebrew):
#
# `brew install graphviz`
#
# Linux (Debian/Ubuntu):
#
# `sudo apt-get update`
#
# `sudo apt-get install graphviz graphviz-dev`
#
# Linux (Fedora/RHEL/CentOS):
#
# `sudo dnf install graphviz graphviz-devel`
#
# Windows:
# 1. Download the installer from https://graphviz.org/download/
# 2. Run the installer and ensure "Add Graphviz to PATH" is selected
# 3. Restart your terminal/IDE after installation
#
# After installing Graphviz, reinstall the Python package:
#
# `pip uninstall pygraphviz`
#
# `pip install pygraphviz`

# %%
from IPython.display import SVG
graph.draw_graphviz(layout="dot", path="KF_simple.svg")
SVG('KF_simple.svg')

# %% [markdown]
# ## KG Visualisation
# Let's make a slightly more beautiful and self-explanatory visualization

# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def visualize_single_graph(graph):
    # Extract triples from the graph
    triples = graph.get_triples()
    G = nx.DiGraph()

    # Collect all types of nodes (subjects, predicates, and objects)
    subjects = {s for s, _, _ in triples}
    objects = {o for _, o, _ in triples}
    predicates = {p for _, _, p in triples}

    # Add nodes and edges based on the triples
    for s, o, p in triples:
        G.add_node(s)
        G.add_node(p)
        G.add_node(o)
        G.add_edge(s, p)
        G.add_edge(p, o)

    # Set the figure size for the visualization
    plt.figure(figsize=(18, 14))
    
    # Layout settings with increased distance between nodes
    pos = nx.spring_layout(G, k=2.0, iterations=200, seed=42)
    
    # Group nodes into categories
    node_groups = {
        "predicates": list(predicates),
        "subjects": list(subjects - predicates - objects),
        "objects": list(objects - subjects - predicates),
        "shared": list((subjects & objects) - predicates)
    }

    # Adjust positions as before...
    def adjust_positions(nodes, dx_pattern, dy_pattern):
        for i, node in enumerate(nodes):
            x, y = pos[node]
            pos[node] = (x + dx_pattern(i), y + dy_pattern(i))

    adjust_positions(node_groups["predicates"], 
                     lambda i: (i % 3) * 5.5, 
                     lambda i: (i // 3) * 5.5)
    adjust_positions(node_groups["subjects"],
                     lambda i: -4.0 - (i % 2) * 3.5,
                     lambda i: 3.0 - (i // 2) * 4.0)
    adjust_positions(node_groups["objects"],
                     lambda i: 4.0 + (i % 2) * 3.5,
                     lambda i: 3.0 - (i // 2) * 4.0)
    adjust_positions(node_groups["shared"],
                     lambda i: (i % 4) * 2.5 - 5.0,
                     lambda i: -4.0 - (i // 4) * 3.0)

    # Styling for different groups of nodes
    node_styles = {
        "predicates": {'color': '#E6E6FA', 'size': 2500, 'ec': 'darkviolet'},
        "subjects":   {'color': '#98FB98', 'size': 2200, 'ec': 'darkgreen'},
        "objects":    {'color': '#FFB6C1', 'size': 2200, 'ec': 'crimson'},
        "shared":     {'color': '#DDA0DD', 'size': 2400, 'ec': 'purple'}
    }

    # Draw nodes
    for group, style in node_styles.items():
        nx.draw_networkx_nodes(
            G, pos, nodelist=node_groups[group],
            node_size=style['size'],
            node_color=style['color'],
            edgecolors=style['ec'],
            alpha=0.8
        )

    # Labels and edges
    nx.draw_networkx_labels(G, pos, font_size=10, font_weight='bold')
    nx.draw_networkx_edges(G, pos, width=2, alpha=0.6, edge_color='gray')
    edge_labels = {(u, v): v if v in predicates else '' for u, v in G.edges()}
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, 
                                 font_size=8, label_pos=0.7,
                                 bbox=dict(alpha=0))

    # Add a legend for the three main node types
    legend_handles = [
        mpatches.Patch(facecolor=node_styles["subjects"]['color'],
                       edgecolor=node_styles["subjects"]['ec'],
                       label='Subjects'),
        mpatches.Patch(facecolor=node_styles["predicates"]['color'],
                       edgecolor=node_styles["predicates"]['ec'],
                       label='Predicates'),
        mpatches.Patch(facecolor=node_styles["objects"]['color'],
                       edgecolor=node_styles["objects"]['ec'],
                       label='Objects'),
    ]
    plt.legend(handles=legend_handles,
               loc='upper right',
               title='Node Types',
               framealpha=0.9)

    # Final touches
    plt.title('Enhanced Knowledge Graph Visualization', fontsize=18)
    plt.axis('off')
    plt.tight_layout(pad=4.0)
    plt.savefig("KF_advanced.png", dpi=300)
    plt.show()

visualize_single_graph(graph)

# %% [markdown]
# Let's use the power of SPARQL in SAP HANA

# %% [markdown]
# #### **Important Setup:**  .env File Required for HANA Cloud Access
#
# Before running the application, ensure that the `.env` file is present in the same directory as the source code. This file contains the necessary credentials for accessing HANA Cloud.
#
# The `.env` file should include the following lines with the appropriate values:
#
#
# > hana_address="xxxxx.hanacloud.ondemand.com"
# > hana_port= "443"
# > hana_user="xxxxx"
# > hana_password="xxxxxx"
# > hana_encrypt="default"
#
#
# #### **Make sure to replace the placeholders (`xxxxxxx`) with your actual HANA Cloud credentials.**

# %%
from hdbcli import dbapi
import os
from typing import Optional

from kg_notebook_helpers import build_run_graph_iri, create_run_id

# Connection parameters are loaded from the explicit notebook .env cell above.
HANA_ADDRESS = os.getenv("hana_address")
HANA_PORT = os.getenv("hana_port")
HANA_USER = os.getenv("hana_user")
HANA_PASSWORD = os.getenv("hana_password")

if not all((HANA_ADDRESS, HANA_PORT, HANA_USER, HANA_PASSWORD)):
    raise RuntimeError("Missing HANA connection values in the notebook .env file.")

GRAPH_RUN_ID = create_run_id()
GRAPH_NAME = "product_KG_pdf2"
HANA_ENV = {
    "hana_address": HANA_ADDRESS,
    "hana_port": HANA_PORT,
    "hana_user": HANA_USER,
    "hana_password": HANA_PASSWORD,
    "graph_run_id": GRAPH_RUN_ID,
}


def connect_hana(hana_env: dict) -> tuple:
    """Open a HANA connection and cursor using the supplied non-secret settings.

    Args:
        hana_env: Mapping containing the HANA address, port, user, and password.

    Returns:
        A ``(connection, cursor)`` tuple ready for HANA SQL or SPARQL work.
    """
    connection = dbapi.connect(
        address=hana_env["hana_address"],
        port=hana_env["hana_port"],
        user=hana_env["hana_user"],
        password=hana_env["hana_password"],
    )
    return connection, connection.cursor()


def close_hana(connection, cursor) -> None:
    """Close a HANA cursor and its owning connection.

    Args:
        connection: Open HANA DB-API connection.
        cursor: Cursor created from ``connection``.

    Returns:
        None. Both resources are closed before returning.
    """
    try:
        cursor.close()
    finally:
        connection.close()


def graph_iri_for(graph_name: str, hana_env: dict = HANA_ENV) -> str:
    """Return the current run's user-owned named graph IRI.

    Args:
        graph_name: Scenario-specific graph label.
        hana_env: Mapping containing the unique graph run identifier.

    Returns:
        A collision-free named graph IRI for this notebook execution.
    """
    return build_run_graph_iri(hana_env["graph_run_id"], graph_name)


def run_hana_preflight(hana_env: dict, graph_name: str) -> tuple[str, str]:
    """Verify HANA authentication and SPARQL query access without changing data.

    Args:
        hana_env: Mapping containing HANA connection and run metadata.
        graph_name: Scenario graph label to display in the preflight result.

    Returns:
        The authenticated database user and the graph IRI reserved for the run.

    Raises:
        RuntimeError: If the user cannot run the read-only SPARQL preflight.
    """
    connection, cursor = connect_hana(hana_env)
    try:
        cursor.execute("SELECT CURRENT_USER FROM DUMMY")
        current_user = str(cursor.fetchone()[0])
        # SPARQL_TABLE accepts only SPARQL SELECT queries. Use SPARQL_EXECUTE for ASK.
        cursor.callproc(
            "SYS.SPARQL_EXECUTE",
            [
                "ASK WHERE { ?s ?p ?o }",
                "Accept: application/sparql-results+json Content-Type: application/sparql-query",
                None,
                None,
            ],
        )
        return current_user, graph_iri_for(graph_name, hana_env)
    except Exception as error:
        raise RuntimeError(
            "HANA SPARQL preflight failed. Verify that Triple Store is enabled and "
            "that the notebook user has EXECUTE on SYS.SPARQL_EXECUTE. DBADMIN can grant it with: "
            "GRANT EXECUTE ON \\\"SYS\\\".\\\"SPARQL_EXECUTE\\\" TO <USER>."
        ) from error
    finally:
        close_hana(connection, cursor)


current_user, preflight_graph_iri = run_hana_preflight(HANA_ENV, GRAPH_NAME)
print(f"[INFO] Connected as HANA user: {current_user}")
print(f"[INFO] User-owned graph for this run: {preflight_graph_iri}")


def to_iri(value: str, base: str = "http://example.com/") -> str:
    """Convert a graph value into a percent-encoded bracketed RDF IRI.

    Args:
        value: Entity or predicate text to encode.
        base: IRI prefix used to namespace the encoded value.

    Returns:
        A bracketed RDF IRI suitable for a SPARQL triple.
    """
    import re

    encoded_part = re.sub(
        r"[^a-zA-Z0-9\-_\.]", lambda match: f"%{ord(match.group(0)):02X}", value
    )
    return f"<{base}{encoded_part}>"


def to_literal(value: Optional[str]) -> str:
    """Escape a Python value as a quoted SPARQL string literal.

    Args:
        value: Text value to escape, or ``None`` for an empty literal.

    Returns:
        A double-quoted SPARQL literal.
    """
    if value is None:
        return '""'
    escaped = (
        value.replace("\\", "\\\\")
        .replace('"', '\"')
        .replace("\n", "\\n")
        .replace("\r", "\\r")
    )
    return f'"{escaped}"'
# Out:
# [INFO] Connected as HANA user: KG_DEMO
# [INFO] User-owned graph for this run: <https://kg-demo.example/runs/a804672bfa804eaab5685d8222499abc/product_KG_pdf2>

# %% [markdown]
# #### Prefixes in SAP HANA SPARQL
#
# In this example, we used <http://example.com/> as the base URI, but you can choose any other. See more about prefixes below.
#
# **What is an IRI?**
# An IRI is an extended URI that allows unique identification of resources (subjects, predicates, and objects) in distributed systems.
#
# **Example of a full IRI:**
# <http://example.com/resource/CompressorMotor123>
#
# **What is a prefix?**
# A prefix is a short alias for a long IRI — it makes writing and reading queries easier.
#
# **Choosing your prefix:**
# Name it according to the task (e.g. `motor:`, `sensor:`, `device:`) and use it consistently.
#
# **Why do you need prefixes:**
# - Reduce the amount of code
# - Improve readability
# - Make it easier to change the base URI
#
# **When to include public ontologies:**
# For standard terms and metadata (RDF, RDFS, schema.org, FOAF, Dublin Core) — to ensure semantic compatibility.
#
# For standard terms and metadata (RDF, RDFS, schema.org, FOAF, Dublin Core) — to ensure semantic compatibility.
#
#
# ```sparql
# PREFIX rdf:   <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs:  <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX schema: <http://schema.org/>
# PREFIX foaf:  <http://xmlns.com/foaf/0.1/>
# PREFIX dc:    <http://purl.org/dc/elements/1.1/>
# ```
#
# For more details on the PREFIX clause in SAP HANA SPARQL, see:
#
# https://help.sap.com/docs/hana-cloud-database/sap-hana-cloud-sap-hana-database-sparql-reference-guide/prefix-clause?locale=en-US

# %%
# Insert the extracted triples into a graph owned by this notebook run.
graph_iri = graph_iri_for(GRAPH_NAME)
triples_statements = []
for subject, object_value, predicate in triples:
    subject_iri = to_iri(subject, base="http://example.com/resource/")
    predicate_iri = to_iri(predicate, base="http://example.com/property/")
    object_literal = to_literal(object_value)
    triples_statements.append(f"    {subject_iri} {predicate_iri} {object_literal} .")

sparql_bulk_insert = f"""
INSERT DATA {{
  GRAPH {graph_iri} {{
{chr(10).join(triples_statements)}
  }}
}}
""".strip()

connection, cursor = connect_hana(HANA_ENV)
try:
    cursor.callproc("SYS.SPARQL_EXECUTE", [sparql_bulk_insert, "", None, None])
    connection.commit()
    print(f"[INFO] Inserted {len(triples)} triples into {graph_iri}.")
except Exception as error:
    raise RuntimeError(
        "SPARQL INSERT failed. Confirm the runtime role has SPARQL UPDATE and rerun "
        "with this fresh graph namespace."
    ) from error
finally:
    close_hana(connection, cursor)
# Out:
# [INFO] Inserted 70 triples into <https://kg-demo.example/runs/a804672bfa804eaab5685d8222499abc/product_KG_pdf2>.

# %%
# Query the graph with a new cursor, then remove this direct-demo graph.
graph_iri = graph_iri_for(GRAPH_NAME)
sparql_query = f"""
SELECT DISTINCT ?s ?p ?o
FROM {graph_iri}
WHERE {{
  # ?s ?p ?o
}}
""".strip()

connection, cursor = connect_hana(HANA_ENV)
try:
    print("[INFO] Executing SPARQL SELECT query...")
    cursor.execute(f"SELECT * FROM SPARQL_TABLE('{sparql_query}')")
    results = cursor.fetchall()
    if results:
        print("[RESULT] Query results:")
        for row in results:
            print(row)
    else:
        print("[RESULT] No data found.")
finally:
    try:
        cursor.callproc("SYS.SPARQL_EXECUTE", [f"DROP GRAPH {graph_iri}", "", None, None])
        connection.commit()
        print(f"[INFO] Dropped direct-demo graph: {graph_iri}")
    except Exception as cleanup_error:
        print(f"[WARN] Could not drop direct-demo graph: {cleanup_error}")
    finally:
        close_hana(connection, cursor)
# Out:
# [INFO] Executing SPARQL SELECT query...
# [RESULT] Query results:
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20temperature%20rating', 'Class B temperature rise')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20temperature%20rating', 'ambient temperature 40°C max / 0°C min')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'Babbitted sleeve bearings with splash lubrication')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'dynamic balancing per NEMA MG 1 Part 7')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'extended rear shaft for main oil lube pump setup')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'main power leads for termination in separate box')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'noise rating per IEEE 85')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'removable filter housing')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stainless steel screens and air filters')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stator insulation system impervious to contaminants')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'vibration readings at upper and lower bearing housings')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/operates%20at%20voltage', '4160V')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'IEEE 43')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ISO 1940/1')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'full load current 180A')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'maximum temperature rise 80°C @ 1.0 SF and 90°C @ 1.15 SF')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'sound level 85 dB(A) at 3 feet at no-load')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20insulation%20class', 'Class F insulation')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20speed%20rating', '3600 RPM')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20power%20rating', '1500 HP')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/provides', 'compatibility with existing monitoring and control devices at the motor controller')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20equipped%20with', 'RTDs for winding temperature detection')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20equipped%20with', 'vibration sensors')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'auxiliary terminal boxes for stator RTD and space heater leads')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'copper or copper alloy rotor bars and end rings')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'main and auxiliary terminal boxes')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'main power lead conductors exiting at same location as existing')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'rigid conduit for accessory equipment wiring')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'sight glasses with fill and drain ports for bearings')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stainless steel nameplate')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'two stainless steel grounding pads')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20protection%20rating', 'NEMA WP I enclosure')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ANSI')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ASTM A345-19')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ASTM A536-84')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'CSA')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'IEEE 522')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'NEMA MG 1')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'locked rotor current 6.3 or less x FLA')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'rated torque at design speed 2188 ft-lb')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'service factor 1.15 @ 105°C')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20equipped%20with', 'space heaters 240V 1 phase 400W')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'copper bus work with plated joints and epoxy insulators')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'instrumentation terminal box at same location as existing')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'severe duty marine grade ANSI 61 gray paint finish')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'slip-on sleeve-type wire markers')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stator core built from low loss high permeability steel laminations')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stator leads with oil resistant insulation')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'zero leakage rate shaft seals')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20protection%20rating', 'stainless steel nameplate per NEMA MG 1-20.60')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20a', 'Equipment')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ASTM E125-63')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ASTM E709-21')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'IEEE 112')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'IEEE 85')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'NEC')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'UL')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'driven load inertia (WR2) at start 520 lb-ft2')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'minimum locked rotor torque 2150 ft-lb')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'vibration not to exceed 0.10 in/sec peak')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20equipped%20with', 'RTDs for bearing temperature detection')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'main oil pump driven by motor shaft')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20protection%20rating', 'IP rating per NEMA MG-1.25')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20protection%20rating', 'Weather-Protected I (WP-I)')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'API 541')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'locked rotor KVA code G')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'minimum breakaway torque at 2413V 600 ft-lb')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'power factor 0.936 or higher')
# ('http://example.com/resource/1500-HP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/operates%20at%20frequency', '60Hz')
# [INFO] Dropped direct-demo graph: <https://kg-demo.example/runs/a804672bfa804eaab5685d8222499abc/product_KG_pdf2>

# %% [markdown]
# ### Let's put everything together into one set of functions to demonstrate how the KG query pipeline works

# %% [markdown]
# ### Function Reference: SAP HANA Knowledge Graph Pipeline
#
# The helpers below create a unique graph namespace for each notebook run, extract PDF triples, persist them through HANA SPARQL, retrieve only selected predicate facts, and remove the temporary graph on completion.
#
# - `extract_and_store_kg_from_pdf(...)` extracts PDF triples and inserts them into this run's graph.
# - `get_unique_predicate_options(...)` returns readable predicate labels mapped to their RDF predicate IRIs.
# - `get_triples_by_predicates(...)` retrieves facts for the selected predicate IRIs without generating invalid SPARQL for an empty selection.
# - `drop_kg_graph(...)` removes the temporary named graph owned by the notebook user.

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.graphs.index_creator import GraphIndexCreator

from kg_notebook_helpers import build_predicate_select_query, predicate_label


def extract_and_store_kg_from_pdf(
    pdf_filename: str,
    graph_name: str,
    extraction_prompt: str,
    chat_llm,
    hana_env: dict,
) -> list[tuple[str, str, str]]:
    """Extract PDF triples and insert them into this run's named HANA graph.

    Args:
        pdf_filename: Path to the user-provided PDF specification.
        graph_name: Scenario-specific graph label.
        extraction_prompt: Prompt used by ``GraphIndexCreator``.
        chat_llm: Configured SAP Gen AI Hub LangChain chat model.
        hana_env: HANA connection and graph-run configuration.

    Returns:
        Extracted ``(subject, object, predicate)`` triples.

    Raises:
        RuntimeError: If HANA rejects the SPARQL insert.
    """
    documents = PyPDFLoader(pdf_filename).load()
    document_text = "This is a compressor specification: " + " ".join(
        document.page_content for document in documents
    )
    triples = GraphIndexCreator(llm=chat_llm).from_text(
        text=document_text,
        prompt=extraction_prompt,
    ).get_triples()

    graph_iri = graph_iri_for(graph_name, hana_env)
    triple_statements = []
    for subject, object_value, predicate in triples:
        subject_iri = to_iri(subject, base="http://example.com/resource/")
        predicate_iri = to_iri(predicate, base="http://example.com/property/")
        object_literal = to_literal(object_value)
        triple_statements.append(f"    {subject_iri} {predicate_iri} {object_literal} .")

    sparql_insert = f"""
    INSERT DATA {{
      GRAPH {graph_iri} {{
{chr(10).join(triple_statements)}
      }}
    }}
    """.strip()

    connection, cursor = connect_hana(hana_env)
    try:
        cursor.callproc("SYS.SPARQL_EXECUTE", [sparql_insert, "", None, None])
        connection.commit()
        print(f"[INFO] Inserted {len(triples)} triples into {graph_iri}.")
    except Exception as error:
        raise RuntimeError(
            "SPARQL INSERT failed. Confirm the runtime role has SPARQL UPDATE and that "
            "the graph belongs to this notebook run."
        ) from error
    finally:
        close_hana(connection, cursor)
    return triples


def get_unique_predicate_options(graph_name: str, hana_env: dict) -> dict[str, str]:
    """Return readable predicate labels mapped to their RDF IRIs for one graph.

    Args:
        graph_name: Scenario-specific graph label.
        hana_env: HANA connection and graph-run configuration.

    Returns:
        Mapping of readable predicate labels to absolute predicate IRIs.
    """
    graph_iri = graph_iri_for(graph_name, hana_env)
    sparql_query = f"""
    SELECT "p"
    FROM SPARQL_TABLE(
      'SELECT DISTINCT ?p
       FROM {graph_iri}
       WHERE {{ ?s ?p ?o }}'
    ) AS "result"
    """.strip()

    connection, cursor = connect_hana(hana_env)
    try:
        cursor.execute(sparql_query)
        predicate_options = {
            predicate_label(str(row[0])): str(row[0])
            for row in cursor.fetchall()
            if row and row[0]
        }
        return dict(sorted(predicate_options.items()))
    finally:
        close_hana(connection, cursor)


def get_triples_by_predicates(
    graph_name: str,
    predicate_iris: list[str],
    hana_env: dict,
) -> list[tuple]:
    """Retrieve graph triples matching the predicates selected for a question.

    Args:
        graph_name: Scenario-specific graph label.
        predicate_iris: Selected absolute predicate IRIs.
        hana_env: HANA connection and graph-run configuration.

    Returns:
        Matching ``(subject, predicate, object)`` rows, or an empty list when none
        are selected.
    """
    sparql_query = build_predicate_select_query(
        graph_iri_for(graph_name, hana_env),
        predicate_iris,
    )
    if sparql_query is None:
        return []

    connection, cursor = connect_hana(hana_env)
    try:
        cursor.execute(sparql_query)
        return cursor.fetchall()
    finally:
        close_hana(connection, cursor)


def drop_kg_graph(graph_name: str, hana_env: dict) -> None:
    """Drop a temporary named graph after a demo scenario completes.

    Args:
        graph_name: Scenario-specific graph label.
        hana_env: HANA connection and graph-run configuration.

    Returns:
        None. Cleanup failures are reported but do not hide the scenario result.
    """
    graph_iri = graph_iri_for(graph_name, hana_env)
    connection, cursor = connect_hana(hana_env)
    try:
        cursor.callproc("SYS.SPARQL_EXECUTE", [f"DROP GRAPH {graph_iri}", "", None, None])
        connection.commit()
        print(f"[INFO] Dropped temporary graph: {graph_iri}")
    except Exception as error:
        print(f"[WARN] Could not drop temporary graph {graph_iri}: {error}")
    finally:
        close_hana(connection, cursor)


# Direct helper demonstration without an LLM relation-selection call.
GRAPH_NAME = "KG_pdf_tmp_01"
try:
    triples = extract_and_store_kg_from_pdf(
        pdf_filename="2312_-_Four_1500-HP_Main_Air_Compressor_Motors_FINAL.pdf",
        graph_name=GRAPH_NAME,
        extraction_prompt=KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT,
        chat_llm=chat_llm,
        hana_env=HANA_ENV,
    )
    predicate_options = get_unique_predicate_options(GRAPH_NAME, HANA_ENV)
    print("Available predicates:", list(predicate_options))
    selected_predicates = [
        predicate_options[label]
        for label in ("has efficiency rating", "operates at voltage")
        if label in predicate_options
    ]
    triples_filtered = get_triples_by_predicates(
        GRAPH_NAME,
        selected_predicates,
        HANA_ENV,
    )
    for triple in triples_filtered:
        print("Triple:", triple)
finally:
    drop_kg_graph(GRAPH_NAME, HANA_ENV)
# Out:
# [INFO] Inserted 224 triples into <https://kg-demo.example/runs/a804672bfa804eaab5685d8222499abc/KG_pdf_tmp_01>.
# Available predicates: ['has bearing', 'has efficiency rating', 'has enclosure', 'has industry standard', 'has insulation class', 'has load characteristic', 'has power rating', 'has protection rating', 'has speed rating', 'has temperature rating', 'is a', 'is designed with', 'is equipped with', 'operates at frequency', 'operates at voltage']
# Triple: ('http://example.com/resource/MAC%201-2', 'http://example.com/property/operates%20at%20voltage', '4160V')
# Triple: ('http://example.com/resource/MAC%201-1', 'http://example.com/property/operates%20at%20voltage', '4160V')
# Triple: ('http://example.com/resource/MAC%202-2', 'http://example.com/property/operates%20at%20voltage', '4160V')
# Triple: ('http://example.com/resource/MAC%202-1', 'http://example.com/property/operates%20at%20voltage', '4160V')
# Triple: ('http://example.com/resource/MAC%201-2', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# Triple: ('http://example.com/resource/MAC%201-1', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# Triple: ('http://example.com/resource/MAC%202-2', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# Triple: ('http://example.com/resource/MAC%202-1', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# [INFO] Dropped temporary graph: <https://kg-demo.example/runs/a804672bfa804eaab5685d8222499abc/KG_pdf_tmp_01>

# %% [markdown]
# ### `ask_llm_simple(prompt: str) -> str`
# Sends a prompt string to a Large Language Model (LLM) and returns the generated response as a string.

# %%
def ask_llm_simple(prompt: str) -> str:
   try:
       llm = ChatOpenAI(proxy_model_name='gpt-4o', proxy_client=proxy_client)
       result = llm.invoke(prompt)
       return result.content
   except Exception as e:
       print(f"⚠️ LLM Call Error: {e} | Prompt (first 100 chars): {prompt[:100]!r}")
       raise

print(ask_llm_simple("1+1"))
# Out:
# 1 + 1 = 2

# %% [markdown]
# ### `filter_predicates_by_business_question(predicate_options, business_question, ask_llm_simple)`
#
# Given readable predicate labels mapped to their RDF IRIs and a business question in plain English, this function uses a Large Language Model to select only relevant predicates. It returns the corresponding RDF IRIs, which can be safely used in a SPARQL `VALUES ?p` clause.

# %%
import ast
import re


def filter_predicates_by_business_question(
    predicate_options: dict[str, str],
    business_question: str,
    ask_llm_simple,
) -> list[str]:
    """Select graph predicate IRIs relevant to a natural-language question.

    Args:
        predicate_options: Mapping of readable labels to RDF predicate IRIs.
        business_question: Natural-language question to answer from graph facts.
        ask_llm_simple: Function that sends a prompt to the configured LLM.

    Returns:
        RDF predicate IRIs selected from ``predicate_options``. Invalid labels and
        malformed LLM output return an empty list.
    """
    predicate_labels = list(predicate_options)
    prompt = (
        "You are helping to analyze business data using a knowledge graph.\n"
        f"Here is a list of predicate labels from the knowledge graph:\n{predicate_labels}\n"
        f"The user asks: \"{business_question}\"\n"
        "Select only the labels directly relevant to answering the question.\n"
        "Return a Python list containing only labels from the supplied list."
    )
    response = ask_llm_simple(prompt).strip()
    list_match = re.search(r"(\[[^\]]*\])", response)
    if not list_match:
        print("[WARN] LLM response did not contain a Python list.")
        return []
    try:
        selected_labels = ast.literal_eval(list_match.group(1))
    except (SyntaxError, ValueError):
        print("[WARN] LLM response contained an invalid Python list.")
        return []
    if not isinstance(selected_labels, list):
        return []
    return [
        predicate_options[label]
        for label in selected_labels
        if isinstance(label, str) and label in predicate_options
    ]


# Example usage with readable labels and the predicate IRIs used by SPARQL.
predicate_options = {
    "has efficiency rating": "http://example.com/property/has%20efficiency%20rating",
    "has insulation class": "http://example.com/property/has%20insulation%20class",
    "has power rating": "http://example.com/property/has%20power%20rating",
    "operates at voltage": "http://example.com/property/operates%20at%20voltage",
}
business_question = "Summarize the energy efficiency of this motor"
relevant_predicate_iris = filter_predicates_by_business_question(
    predicate_options,
    business_question,
    ask_llm_simple,
)
print("Relevant predicate IRIs:", relevant_predicate_iris)
# Out:
# Relevant predicate IRIs: ['http://example.com/property/has%20efficiency%20rating']

# %% [markdown]
# ## Graph RAG

# %% [markdown]
# ### Scenario 1
#
# In this example, a procurement expert receives a PDF document with the technical specifications for an industrial motor. Instead of searching manually through the document for important details, the engineer uses an automated system to extract a structured knowledge graph from the PDF. Next, the engineer asks a business question such as, “Summarize the energy efficiency of this motor.” The system automatically determines which characteristics in the knowledge graph are relevant for energy efficiency, retrieves those facts, and uses a language model (LLM) to generate a short, clear summary in response to the question. This way, the engineer quickly gets exactly the information needed, saving time and avoiding manual work.

# %%
business_question = "Summarize the energy efficiency of this motor."
pdf_filename = "A700000006779737.pdf"  # User-provided equipment specification.
GRAPH_NAME = "KG_pdf_demo_01"
summary = None

try:
    triples = extract_and_store_kg_from_pdf(
        pdf_filename=pdf_filename,
        graph_name=GRAPH_NAME,
        extraction_prompt=KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT,
        chat_llm=chat_llm,
        hana_env=HANA_ENV,
    )
    predicate_options = get_unique_predicate_options(GRAPH_NAME, HANA_ENV)
    print("Available predicate labels:", list(predicate_options))

    relevant_predicate_iris = filter_predicates_by_business_question(
        predicate_options,
        business_question,
        ask_llm_simple,
    )
    print(
        "Relevant predicate labels:",
        [predicate_label(predicate_iri) for predicate_iri in relevant_predicate_iris],
    )

    triples_for_summary = get_triples_by_predicates(
        GRAPH_NAME,
        relevant_predicate_iris,
        HANA_ENV,
    )
    print("Triples selected for summary:", triples_for_summary)

    if triples_for_summary:
        summary_prompt = (
            "You are an equipment expert. Given the following technical facts:\n"
            f"{triples_for_summary}\n"
            f"Please provide a concise summary that answers this question: {business_question}\n"
        )
        summary = ask_llm_simple(summary_prompt)
        print("=" * 60)
        print("Summary:\n", summary)
        print("=" * 60)
    else:
        print("No relevant facts were found for this question in the current knowledge graph.")
finally:
    drop_kg_graph(GRAPH_NAME, HANA_ENV)
# Out:
# [INFO] Inserted 26 triples into <https://kg-demo.example/runs/a804672bfa804eaab5685d8222499abc/KG_pdf_demo_01>.
# Available predicate labels: ['has efficiency rating', 'has industry standard', 'has insulation class', 'has load characteristic', 'has power rating', 'has protection rating', 'has temperature rating', 'includes', 'is a', 'is designed with', 'is equipped with', 'operates at frequency', 'operates at voltage']
# Relevant predicate labels: ['has efficiency rating', 'operates at voltage', 'operates at frequency']
# Triples selected for summary: [('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20efficiency%20rating', 'IE3 efficiency class'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/operates%20at%20frequency', '50Hz ± 2%'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20efficiency%20rating', '80.8% at 75% load'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/operates%20at%20voltage', '230V/400V ± 5%'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20efficiency%20rating', '78.5% at 50% load'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20efficiency%20rating', '80.7% at 100% load')]
# ============================================================
# Summary:
#  The RS PRO 3 Phase AC motor has an IE3 efficiency class, indicating high energy efficiency. Its specific efficiency ratings are 78.5% at 50% load, 80.8% at 75% load, and 80.7% at 100% load. These values demonstrate consistent efficiency across varying load levels, with peak performance near 75% load.
# ============================================================
# [INFO] Dropped temporary graph: <https://kg-demo.example/runs/a804672bfa804eaab5685d8222499abc/KG_pdf_demo_01>

# %%
if summary is None:
    print("No summary was produced because no relevant graph facts were available.")
else:
    print(summary)
# Out:
# The RS PRO 3 Phase AC motor has an IE3 efficiency class, indicating high energy efficiency. Its specific efficiency ratings are 78.5% at 50% load, 80.8% at 75% load, and 80.7% at 100% load. These values demonstrate consistent efficiency across varying load levels, with peak performance near 75% load.

# %% [markdown]
# ### Scenario 2
#
# In this scenario, a procurement expert is reviewing two different industrial motors to decide if one can be used as a replacement for the other. The expert receives two PDF documents, each with the technical specifications for one of the motors. Instead of comparing details manually, the expert uses an automated system to extract a knowledge graph from each PDF. The expert then asks a specific business question, such as, “Can Motor B replace Motor A in our setup? Please focus on power rating and other key technical attributes.” The system identifies which properties in the knowledge graphs are important for this decision, retrieves the relevant facts from both motors, and uses a language model (LLM) to provide a clear, side-by-side comparison based on the business requirements. This helps the expert make an informed decision quickly and with confidence.

# %%
pdf_filename_a = "A700000008070326.pdf"  # Motor A
pdf_filename_b = "A700000006779737.pdf"  # Motor B
graph_name_a = "KG_motor_A"
graph_name_b = "KG_motor_B"
business_question = (
    "Can Motor B replace Motor A in our setup? "
    "Please focus on power rating and any other important technical attributes."
)
comparison = None

try:
    extract_and_store_kg_from_pdf(
        pdf_filename=pdf_filename_a,
        graph_name=graph_name_a,
        extraction_prompt=KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT,
        chat_llm=chat_llm,
        hana_env=HANA_ENV,
    )
    extract_and_store_kg_from_pdf(
        pdf_filename=pdf_filename_b,
        graph_name=graph_name_b,
        extraction_prompt=KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT,
        chat_llm=chat_llm,
        hana_env=HANA_ENV,
    )

    predicate_options_a = get_unique_predicate_options(graph_name_a, HANA_ENV)
    predicate_options_b = get_unique_predicate_options(graph_name_b, HANA_ENV)
    all_predicate_options = {**predicate_options_a, **predicate_options_b}
    print("Available predicate labels:", list(all_predicate_options))

    relevant_predicate_iris = filter_predicates_by_business_question(
        all_predicate_options,
        business_question,
        ask_llm_simple,
    )
    triples_a_relevant = get_triples_by_predicates(
        graph_name_a,
        relevant_predicate_iris,
        HANA_ENV,
    )
    triples_b_relevant = get_triples_by_predicates(
        graph_name_b,
        relevant_predicate_iris,
        HANA_ENV,
    )
    print("Motor A relevant triples:", triples_a_relevant)
    print("Motor B relevant triples:", triples_b_relevant)

    if triples_a_relevant or triples_b_relevant:
        comparison_prompt = (
            "You are a technical expert. Here are the relevant technical facts for Motor A:\n"
            f"{triples_a_relevant}\n"
            "And here are the relevant facts for Motor B:\n"
            f"{triples_b_relevant}\n"
            f"Based on these, answer the following business question: {business_question}\n"
            "Give a clear, practical comparison and say whether Motor B can reasonably replace Motor A."
        )
        comparison = ask_llm_simple(comparison_prompt)
        print("=" * 60)
        print("Replacement comparison summary:\n", comparison)
        print("=" * 60)
    else:
        print("No relevant facts were found in either temporary graph.")
finally:
    drop_kg_graph(graph_name_a, HANA_ENV)
    drop_kg_graph(graph_name_b, HANA_ENV)
# Out:
# [INFO] Inserted 61 triples into <https://kg-demo.example/runs/a804672bfa804eaab5685d8222499abc/KG_motor_A>.
# [INFO] Inserted 30 triples into <https://kg-demo.example/runs/a804672bfa804eaab5685d8222499abc/KG_motor_B>.
# Available predicate labels: ['has efficiency rating', 'has industry standard', 'has insulation class', 'has load characteristic', 'has power rating', 'has protection rating', 'has speed rating', 'has temperature rating', 'is a', 'is designed with', 'is equipped with', 'operates at frequency', 'operates at voltage']
# Motor A relevant triples: [('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20temperature%20rating', '-20°C to +40°C ambient temperature'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20protection%20rating', 'IP55'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20efficiency%20rating', '90.0% at 460V Δ 60Hz full load'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20load%20characteristic', 'full load current 4.60A at 690V Y 50Hz'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20load%20characteristic', 'full load current 7.90A at 400V Δ 50Hz'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20load%20characteristic', 'locked rotor time cold 21.7s'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20load%20characteristic', 'power factor 0.82 at 690V Y 50Hz full load'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20speed%20rating', '1460 RPM at 50Hz'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20power%20rating', '3.70 kW at 460V Δ 60Hz'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20power%20rating', '4.00 kW at 690V Y 50Hz'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/operates%20at%20voltage', '690V Y'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20efficiency%20rating', '89.4% at 460V Δ 60Hz full load'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20load%20characteristic', 'color RAL7030'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20load%20characteristic', 'direction of rotation bidirectional'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20load%20characteristic', 'power factor 0.82 at 400V Δ 50Hz full load'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20load%20characteristic', 'sound level 58.0 dB(A) at 50Hz'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20load%20characteristic', 'sound level 62.0 dB(A) at 50Hz'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20insulation%20class', '155(F) to 130(B)'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20power%20rating', '4.00 kW at 400V Δ 50Hz'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/operates%20at%20voltage', '460V Δ'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20efficiency%20rating', '89.2% at 690V Y 50Hz full load'), ('http://example.com/resource/1AV3112B%20SIMOTICS%20GP%20-%20112%20M%20-%20IM%20B5%20-%204p', 'http://example.com/property/has%20load%20characteristic', 'bearing lifetim ...
# Motor B relevant triples: [('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20efficiency%20rating', 'IE3 efficiency class'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20load%20characteristic', 'breakdown torque 3.15 Mk/Mn'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/operates%20at%20frequency', '50Hz ± 2%'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20power%20rating', '0.75kW'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20protection%20rating', 'IP56'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20efficiency%20rating', '80.8% at 75% load'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20load%20characteristic', 'rated speed 2885 rpm'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20load%20characteristic', 'rated torque 2.48 Nm'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20load%20characteristic', 'locked rotor current 6 IA/IN Y'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20insulation%20class', 'Class F (155°C)'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20temperature%20rating', 'temperature rise 80K'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/operates%20at%20voltage', '230V/400V ± 5%'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20efficiency%20rating', '78.5% at 50% load'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20efficiency%20rating', '80.7% at 100% load'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20load%20characteristic', 'locked rotor torque 2.4 MA/MN Y'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20load%20characteristic', 'no-load current 1.05A Y'), ('http://example.com/resource/RS%20PRO%203%20Phase%20AC%20motor', 'http://example.com/property/has%20load%20characteristic', 'rated current 1.6A Δ')]
# ============================================================
# Replacement comparison summary:
#  To evaluate whether Motor B can replace Motor A in your setup, we need to closely analyze the technical specifications of both motors, particularly regarding their **power rating** and other relevant parameters. Here's a breakdown and comparison:
#
# ---
#
# ### **1. Power Rating:**
# - **Motor A:**
#   - Up to **4.55 kW** at **460V Δ 60Hz**
#   - 4.00 kW at **690V Y / 400V Δ 50Hz**
#
# - **Motor B:**
#   - **0.75 kW** at **230V/400V ±5%**
#
# **Conclusion:**
# Motor B has a much lower power output (0.75 kW compared to up to 4.55 kW for Motor A). If your setup requires 4 kW+ power output, **Motor B cannot replace Motor A**.
# Power rating is a critical factor and Motor B significantly falls short of the required output.
#
# ---
#
# ### **2. Efficiency Rating:**
# - **Motor A:**
#   - 90.0% efficiency at **460V Δ 60Hz** full load
#   - 89.4% efficiency at 400V Δ 50Hz full load
#
# - **Motor B:**
#   - **80.8% at 75% load**
#   - **80.7% at 100% load**
#   - **78.5% at 50% load**
#   - Efficiency class **IE3**
#
# **Conclusion:**
# Motor A is considerably more energy-efficient across its operating points compared to Motor B. The higher efficiency (>89%) of Motor A means less energy loss during operation, which is advantageous, especially for long operational hours.
#
# ---
#
# ### **3. Speed Ratings:**
# - **Motor A:**
#   - 1460 RPM at **50Hz**
#   - 1770 RPM at **60Hz**
#
# - **Motor B:**
#   - Rated speed **2885 RPM** at **50Hz ± 2%**
#
# **Conclusion:**
# Motor B operates at a much higher speed than Motor A. If your setup requires lower-speed operation (as Motor A provides 1460-1770 RPM), Motor B may not align with your requirements.
#
# ---
#
# ### **4. Current Ratings:**
# - **Motor A:**
#   - Full-load current:
#     - **4.60A at 690V Y 50Hz**
#     - **7.90A at 400V Δ 50Hz**
#     - **6.50A to 7.70A at 460V Δ 60Hz**
#
# - **Motor B:**
#   - Rated current: **1.6A Δ** and **locked rotor current: 6 IA/IN Y**
#
# **Conclusion:**
# Motor B has a much lower current rating compared to Motor A. If your setup demands higher operational current (as required by Motor A), then **Motor B cannot handle the load**.
#
# ---
#
# ### **5. Protection Rating:**
# - **Motor A:** **IP55**
# - **Motor B:** **IP56**
#
# **Conclusion:**
# Motor B provides slightly better protection against dust and water ingress (IP56 vs. IP55). However, this is not a decisive factor given that both ratings are close.
#
# ---
#
# ### **6. Insulation and Temperature:**
# - **Motor A:**
#   - Insulation Class **155(F) to 130(B)**
#   - Ambient temperature: **-20°C to +40°C**
#
# - **Motor B:**
#   - Insulation Class **F (155°C)**
#   - Temperature rise **80K**
#
# **Conclusion:**
# Both motors offer similar insulation class (Class F), but Motor B has no explicit ambient temperature specifications. This might raise concerns in environments where ambient conditions exceed 40°C or drop below -20°C.
#
# ---
#
# ### **7. Frequency and Voltage:**
# - **Motor A:** Operates at **50Hz** and **60Hz**, with voltage ratings of **690V Y**, **460V Δ**, and **400V Δ**.
# - **Motor B:** Operates at **50Hz ±2%** and voltage ratings of **230V/400V ±5%**.
#
# **Conclusion:**
# Motor A can handle higher voltage ratings and dual frequencies (50Hz and 60Hz), while Motor B is limited to 230V/400V and 50Hz. If your setup requires 60Hz or high-voltage operation (like 460V or 690V), **Motor B cannot replace Motor A**.
#
# ---
#
# ### **8. Additional Considerations:**
# - **Torque:**
#   Motor A's torque ratings are not explicitly listed, but Motor B has much lower torque values (e.g., rated torque 2.48 Nm, locked rotor torque 2.4 MA/MN Y). If high torque is critical in your setup, Motor B could underperform.
# - **Duty Type:**
#   Motor A is rated for continuous operation (**S1 duty type**), ensuring longevity and reliability under extended loads. Motor B lacks detailed duty type specifications, but this should be confirmed if considering Motor B.
# - **Physical Attributes:**
#   Motor A has higher locked rotor times (cold: 21.7s; hot: 16s) vs. B, suggesting better performance during start and overload.
#
# ---
#
# ### **Conclusion & Recommendation:**
# No, **Motor B cannot reasonably replace Motor A** without significant changes in the setup and operation expectations.
#
# - Motor B is drastically underpowered compared to Motor A and performs less efficiently, especially in full-load conditions.
# - Motor A is designed for high-power and dual-frequency operations (50Hz and 60Hz frequencies, higher RPM range, higher current/voltage ratings), while Motor B operates exclusively at lower voltage (230V/400V ± 5%) and 50Hz ± 2%.
# - The lack of high torque specifications in Motor B further suggests potential underperformance in applications requiring substantial mechanical force.
#
# If your setup critically relies on the technical attributes of Motor A (high power, efficiency, or low-speed operation), you should **not replace Motor A with Motor B**. Instead, look for a motor with specifications closer to those of Motor A.
# ============================================================
# [INFO] Dropped temporary graph: <https://kg-demo.example/runs/a804672bfa804eaab5685d8222499abc/KG_motor_A>
# [INFO] Dropped temporary graph: <https://kg-demo.example/runs/a804672bfa804eaab5685d8222499abc/KG_motor_B>

# %%
if comparison is None:
    print("No comparison was produced because no relevant graph facts were available.")
else:
    print(comparison)
# Out:
# To evaluate whether Motor B can replace Motor A in your setup, we need to closely analyze the technical specifications of both motors, particularly regarding their **power rating** and other relevant parameters. Here's a breakdown and comparison:
#
# ---
#
# ### **1. Power Rating:**
# - **Motor A:**
#   - Up to **4.55 kW** at **460V Δ 60Hz**
#   - 4.00 kW at **690V Y / 400V Δ 50Hz**
#
# - **Motor B:**
#   - **0.75 kW** at **230V/400V ±5%**
#
# **Conclusion:**
# Motor B has a much lower power output (0.75 kW compared to up to 4.55 kW for Motor A). If your setup requires 4 kW+ power output, **Motor B cannot replace Motor A**.
# Power rating is a critical factor and Motor B significantly falls short of the required output.
#
# ---
#
# ### **2. Efficiency Rating:**
# - **Motor A:**
#   - 90.0% efficiency at **460V Δ 60Hz** full load
#   - 89.4% efficiency at 400V Δ 50Hz full load
#
# - **Motor B:**
#   - **80.8% at 75% load**
#   - **80.7% at 100% load**
#   - **78.5% at 50% load**
#   - Efficiency class **IE3**
#
# **Conclusion:**
# Motor A is considerably more energy-efficient across its operating points compared to Motor B. The higher efficiency (>89%) of Motor A means less energy loss during operation, which is advantageous, especially for long operational hours.
#
# ---
#
# ### **3. Speed Ratings:**
# - **Motor A:**
#   - 1460 RPM at **50Hz**
#   - 1770 RPM at **60Hz**
#
# - **Motor B:**
#   - Rated speed **2885 RPM** at **50Hz ± 2%**
#
# **Conclusion:**
# Motor B operates at a much higher speed than Motor A. If your setup requires lower-speed operation (as Motor A provides 1460-1770 RPM), Motor B may not align with your requirements.
#
# ---
#
# ### **4. Current Ratings:**
# - **Motor A:**
#   - Full-load current:
#     - **4.60A at 690V Y 50Hz**
#     - **7.90A at 400V Δ 50Hz**
#     - **6.50A to 7.70A at 460V Δ 60Hz**
#
# - **Motor B:**
#   - Rated current: **1.6A Δ** and **locked rotor current: 6 IA/IN Y**
#
# **Conclusion:**
# Motor B has a much lower current rating compared to Motor A. If your setup demands higher operational current (as required by Motor A), then **Motor B cannot handle the load**.
#
# ---
#
# ### **5. Protection Rating:**
# - **Motor A:** **IP55**
# - **Motor B:** **IP56**
#
# **Conclusion:**
# Motor B provides slightly better protection against dust and water ingress (IP56 vs. IP55). However, this is not a decisive factor given that both ratings are close.
#
# ---
#
# ### **6. Insulation and Temperature:**
# - **Motor A:**
#   - Insulation Class **155(F) to 130(B)**
#   - Ambient temperature: **-20°C to +40°C**
#
# - **Motor B:**
#   - Insulation Class **F (155°C)**
#   - Temperature rise **80K**
#
# **Conclusion:**
# Both motors offer similar insulation class (Class F), but Motor B has no explicit ambient temperature specifications. This might raise concerns in environments where ambient conditions exceed 40°C or drop below -20°C.
#
# ---
#
# ### **7. Frequency and Voltage:**
# - **Motor A:** Operates at **50Hz** and **60Hz**, with voltage ratings of **690V Y**, **460V Δ**, and **400V Δ**.
# - **Motor B:** Operates at **50Hz ±2%** and voltage ratings of **230V/400V ±5%**.
#
# **Conclusion:**
# Motor A can handle higher voltage ratings and dual frequencies (50Hz and 60Hz), while Motor B is limited to 230V/400V and 50Hz. If your setup requires 60Hz or high-voltage operation (like 460V or 690V), **Motor B cannot replace Motor A**.
#
# ---
#
# ### **8. Additional Considerations:**
# - **Torque:**
#   Motor A's torque ratings are not explicitly listed, but Motor B has much lower torque values (e.g., rated torque 2.48 Nm, locked rotor torque 2.4 MA/MN Y). If high torque is critical in your setup, Motor B could underperform.
# - **Duty Type:**
#   Motor A is rated for continuous operation (**S1 duty type**), ensuring longevity and reliability under extended loads. Motor B lacks detailed duty type specifications, but this should be confirmed if considering Motor B.
# - **Physical Attributes:**
#   Motor A has higher locked rotor times (cold: 21.7s; hot: 16s) vs. B, suggesting better performance during start and overload.
#
# ---
#
# ### **Conclusion & Recommendation:**
# No, **Motor B cannot reasonably replace Motor A** without significant changes in the setup and operation expectations.
#
# - Motor B is drastically underpowered compared to Motor A and performs less efficiently, especially in full-load conditions.
# - Motor A is designed for high-power and dual-frequency operations (50Hz and 60Hz frequencies, higher RPM range, higher current/voltage ratings), while Motor B operates exclusively at lower voltage (230V/400V ± 5%) and 50Hz ± 2%.
# - The lack of high torque specifications in Motor B further suggests potential underperformance in applications requiring substantial mechanical force.
#
# If your setup critically relies on the technical attributes of Motor A (high power, efficiency, or low-speed operation), you should **not replace Motor A with Motor B**. Instead, look for a motor with specifications closer to those of Motor A.
