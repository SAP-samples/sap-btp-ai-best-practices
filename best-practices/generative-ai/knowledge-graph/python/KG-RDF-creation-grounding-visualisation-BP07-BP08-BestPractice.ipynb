# %% [markdown]
# # Knowledge Graph Grounding for LLMs in SAP Ecosystem
#
# The *Knowledge Graph Grounding for LLMs* initiative showcases the application of Retrieval-Augmented Generation (RAG) in integrating a Language Model (LLM) with data structured within a Knowledge Graph. This solution encapsulates the entire process, from constructing the Knowledge Graph (KG) from unstructured raw text to building a functional Chat application that can query and interact with this knowledge base.
#
# As part of this R&D project, the following objectives are targeted:
#
# 1. **Evaluate LangChain Tools for Knowledge Graph Integration:** - Assess the LangChain ecosystem and its ability to handle interactions with Knowledge Graphs effectively. Specifically, this involves exploring LangChains tools to integrate various data sources, including enterprise-specific databases, into an LLM model.
#
# 2. **LLM-Assisted Knowledge Graph Construction:** - Investigate the feasibility of leveraging LLMs to automate the construction of Knowledge Graphs directly from raw text data. This includes exploring techniques for extracting entities, relationships, and attributes from structured and unstructured data sources, and how LLMs can assist in enhancing the accuracy and automation of this process.
#
# 3. **Evaluate Triplestore (RDF Store) in HANA Cloud:** - Conduct a hands-on evaluation of working with SAPs HANA Cloud triplestore, an RDF store, which is in Beta at the time of writing. The focus will be on assessing its developer experience, performance, and integration with SAPs broader ecosystem, especially its compatibility with other enterprise systems for managing semantic data.
#
# ### Potential Use Cases in SAP:
#
# - **Enterprise Data Integration:** - By grounding LLMs with a Knowledge Graph, SAP systems can significantly enhance data integration and retrieval processes across multiple sources, improving the accuracy and speed of decision-making. This approach can be applied in areas such as finance, procurement, or customer relationship management (CRM).
#
# - **Intelligent Chatbots for Enterprise Applications:** - The constructed Knowledge Graph can be used to power intelligent chatbots integrated into SAP S4HANA or SAP Fiori applications. These chatbots could assist employees with querying operational data, guiding them through business processes, or providing data-driven insights.
#
# - **Automated Data Modeling:** - Using LLMs to assist in the automated creation of Knowledge Graphs from raw text could significantly reduce the time and effort required for data modeling, particularly in complex enterprise systems where textual data is abundant (e.g., contracts, specifications, manuals).
#
# - **Enhanced Business Intelligence (BI):** - Grounding LLMs with structured data stored in a Knowledge Graph can facilitate advanced business intelligence applications. By querying the KG for insights, users can gain a deeper understanding of trends, performance, and operational bottlenecks in real-time.
#
# - **Semantic Search in SAP Solutions:** - Knowledge Graph grounding could enable more advanced semantic search capabilities in SAP solutions, allowing users to query data using natural language and retrieve contextually relevant results rather than relying on traditional keyword-based searches.
#
# **Data sample:**
#
# - https://www.ebmud.com/application/files/3416/7771/2399/2312_-_Four_1500-HP_Main_Air_Compressor_Motors_FINAL.pdf
# - https://docs.rs-online.com/d853/A700000006779737.pdf
# - https://docs.rs-online.com/aee6/A700000008070326.pdf
#
# but you can use your own data in pdf format.
#
#
# This integration of LLMs with SAP Knowledge Graphs has the potential to transform how organizations manage, retrieve, and utilize enterprise data, particularly in environments that rely heavily on large volumes of unstructured or semi-structured data.
#
# The results of your run may differ from the results in this notebook. Try, improve!

# %% [markdown]
# ![image.png](attachment:ca3d4b49-8ed1-43e6-ae18-ae906671ce91.png)
#
# #### **Important Setup:**  .env File Required for AI CORE Access
#
# Before running the application, ensure that the `.env` file is present in the same directory as the source code. This file contains the necessary credentials for accessing AI CORE.
#
# The `.env` file should include the following lines with the appropriate values:
#
# > AICORE_AUTH_URL="https://*xxxxxxx.authentication.eu10.hana.ondemand.com"
# > AICORE_CLIENT_ID= "xxxxxxxx"
# > AICORE_CLIENT_SECRET="xxxxx"
# > AICORE_BASE_URL="https://api.xxxxxxxx.hana.ondemand.com/v2"
# > AICORE_RESOURCE_GROUP="default"
#
#
# **Make sure to replace the placeholders (`xxxxxxx`) with your actual AI CORE credentials.**

# %% [markdown]
# Environment Setup
# This  block handles the setup of the environment.
# It loads necessary credentials and configurations from a .env file.
# Ensure your .env file includes AICORE access details before proceeding.

# %%
from dotenv import load_dotenv
_ = load_dotenv()

# %%
# Install necessary packages (langchain, rdflib, networkx, matplotlib etc.)
import os
import re
from gen_ai_hub.proxy.langchain.openai import ChatOpenAI
from gen_ai_hub.proxy.core.proxy_clients import get_proxy_client


# Create a proxy client for the AI Hub
proxy_client = get_proxy_client('gen-ai-hub')
chat_llm = ChatOpenAI(proxy_model_name='gpt-4.1', proxy_client=proxy_client, temperature=0.0)
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %% [markdown]
# ## Data Ingestion
# Import raw data from the source. Build the Knowledge Graph using a Language Model (LLM)

# %%
from langchain.indexes.graph import GraphIndexCreator
from langchain_community.document_loaders import PyPDFLoader
from prompts import KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT

loader = PyPDFLoader("2312_-_Four_1500-HP_Main_Air_Compressor_Motors_FINAL.pdf")
docs = loader.load()
doc_content = 'This is a compressor specification: '
for doc in docs:
    doc_content = doc_content + ' ' + doc.page_content

index_creator = GraphIndexCreator(llm=chat_llm)

graph = index_creator.from_text(text=doc_content, prompt=KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT)

# %% [markdown]
# ## Extracted Triples

# %% [markdown]
#  **Objective:** Extract knowledge triples (subject-predicate-object) from the given text.
#
#  **Method:** Use a pre-defined prompt and the OpenAI API to instruct the LLM to extract triples.

# %%
triples  = graph.get_triples()
print(triples)
# Out:
# [('1500-HP Main Air Compressor Motor', 'Equipment', 'is a'), ('1500-HP Main Air Compressor Motor', '1500 HP', 'has power rating'), ('1500-HP Main Air Compressor Motor', '4160V', 'operates at voltage'), ('1500-HP Main Air Compressor Motor', '60Hz', 'operates at frequency'), ('1500-HP Main Air Compressor Motor', '3600 RPM', 'has speed rating'), ('1500-HP Main Air Compressor Motor', '95% or higher at 100% load', 'has efficiency rating'), ('1500-HP Main Air Compressor Motor', 'power factor 0.936 or higher', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'locked rotor current 6.3 or less x FLA', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'service factor 1.15 @ 105°C', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'ambient temperature 40°C maximum', 'has temperature rating'), ('1500-HP Main Air Compressor Motor', 'Class B temperature rise', 'has temperature rating'), ('1500-HP Main Air Compressor Motor', 'Class F insulation', 'has insulation class'), ('1500-HP Main Air Compressor Motor', 'NEMA WP I enclosure', 'has protection rating'), ('1500-HP Main Air Compressor Motor', 'Weather-Protected I (WP-I)', 'has protection rating'), ('1500-HP Main Air Compressor Motor', 'vibration sensors', 'is equipped with'), ('1500-HP Main Air Compressor Motor', 'winding temperature sensors (RTDs)', 'is equipped with'), ('1500-HP Main Air Compressor Motor', 'bearing temperature sensors (RTDs)', 'is equipped with'), ('1500-HP Main Air Compressor Motor', 'space heaters', 'is equipped with'), ('1500-HP Main Air Compressor Motor', 'main and auxiliary terminal boxes', 'is equipped with'), ('1500-HP Main Air Compressor Motor', 'copper or copper alloy rotor bars and end rings', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'non-hygroscopic insulation system', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'sealed insulation system meeting NEMA MG 1 2.27.2', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'Babbitted sleeve bearings with splash lubrication', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'stator RTDs: twelve (four per phase)', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'four bearing RTDs (two per front and rear bearing)', 'is designed with'), ('1500-HP Main Air Compressor Motor', '1/4-28 tap on each bearing housing for tri-axial accelerometer-type vibration sensors', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'motor shaft extension to drive main oil lube pump', 'is designed with'), ('1500-HP Main Air Compressor Motor', 'Babbitted sleeve bearings', 'has bearing'), ('1500-HP Main Air Compressor Motor', 'NEMA WP I', 'has enclosure'), ('1500-HP Main Air Compressor Motor', '6809-H', 'has frame'), ('1500-HP Main Air Compressor Motor', 'full load torque 2188 ft-lb', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'minimum locked rotor torque 2150 ft-lb', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'starting method: reduced voltage autotransformer', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'minimum breakaway torque at 2413 volts 600 ft-lb', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'driven load inertia (WR2) at start 520 lb-ft2', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'transient reactance 0.140 pu', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'duty: continuous 90°C @ 1.15 SF', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'slip and full-load rpm data required', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'speed vs. torque and current curves at 4160V required', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'full-load amperes at 4160V required', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'no-load amperes at 4160V required', 'has load characteristic'), ('1500-HP Main Air Compressor Motor', 'locke ...

# %%
triples[0][0]
# Out:
# '1500-HP Main Air Compressor Motor'

# %% [markdown]
# ## KG - Simple Visualization
# from langchain.indexes.graph - sometimes ready-made and quick visualizations don't look very nice
#
# ### Graphviz Installation Instructions
# For the following code to work and plot the graphs, you need to install Graphviz.
#
# macOS (using Homebrew):
#
# `brew install graphviz`
#
# Linux (Debian/Ubuntu):
#
# `sudo apt-get update`
#
# `sudo apt-get install graphviz graphviz-dev`
#
# Linux (Fedora/RHEL/CentOS):
#
# `sudo dnf install graphviz graphviz-devel`
#
# Windows:
# 1. Download the installer from https://graphviz.org/download/
# 2. Run the installer and ensure "Add Graphviz to PATH" is selected
# 3. Restart your terminal/IDE after installation
#
# After installing Graphviz, reinstall the Python package:
#
# `pip uninstall pygraphviz`
#
# `pip install pygraphviz`

# %%
from IPython.display import SVG
graph.draw_graphviz(layout="dot", path="KF_simple.svg")
SVG('KF_simple.svg')

# %% [markdown]
# ## KG Visualisation
# Let's make a slightly more beautiful and self-explanatory visualization

# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def visualize_single_graph(graph):
    # LangChain returns triples as (subject, object, predicate)
    triples = graph.get_triples()
    G = nx.DiGraph()

    # Collect all types of nodes
    subjects = {s for s, _, _ in triples}
    objects = {o for _, o, _ in triples}
    predicates = {p for _, _, p in triples}

    # Add nodes and edges based on the triples
    for s, o, p in triples:
        G.add_node(s)
        G.add_node(p)
        G.add_node(o)
        G.add_edge(s, p)
        G.add_edge(p, o)

    plt.figure(figsize=(18, 14))
    pos = nx.spring_layout(G, k=2.0, iterations=200, seed=42)

    node_groups = {
        "predicates": list(predicates),
        "subjects": list(subjects - predicates - objects),
        "objects": list(objects - subjects - predicates),
        "shared": list((subjects & objects) - predicates)
    }

    def adjust_positions(nodes, dx_pattern, dy_pattern):
        for i, node in enumerate(nodes):
            x, y = pos[node]
            pos[node] = (x + dx_pattern(i), y + dy_pattern(i))

    adjust_positions(node_groups["predicates"],
                     lambda i: (i % 3) * 5.5,
                     lambda i: (i // 3) * 5.5)
    adjust_positions(node_groups["subjects"],
                     lambda i: -4.0 - (i % 2) * 3.5,
                     lambda i: 3.0 - (i // 2) * 4.0)
    adjust_positions(node_groups["objects"],
                     lambda i: 4.0 + (i % 2) * 3.5,
                     lambda i: 3.0 - (i // 2) * 4.0)
    adjust_positions(node_groups["shared"],
                     lambda i: (i % 4) * 2.5 - 5.0,
                     lambda i: -4.0 - (i // 4) * 3.0)

    node_styles = {
        "predicates": {'color': '#E6E6FA', 'size': 2500, 'ec': 'darkviolet'},
        "subjects":   {'color': '#98FB98', 'size': 2200, 'ec': 'darkgreen'},
        "objects":    {'color': '#FFB6C1', 'size': 2200, 'ec': 'crimson'},
        "shared":     {'color': '#DDA0DD', 'size': 2400, 'ec': 'purple'}
    }

    for group, style in node_styles.items():
        nx.draw_networkx_nodes(
            G, pos, nodelist=node_groups[group],
            node_size=style['size'],
            node_color=style['color'],
            edgecolors=style['ec'],
            alpha=0.8
        )

    nx.draw_networkx_labels(G, pos, font_size=10, font_weight='bold')
    nx.draw_networkx_edges(G, pos, width=2, alpha=0.6, edge_color='gray')

    edge_labels = {(u, v): v if v in predicates else '' for u, v in G.edges()}
    nx.draw_networkx_edge_labels(
        G, pos,
        edge_labels=edge_labels,
        font_size=8,
        label_pos=0.7,
        bbox=dict(alpha=0)
    )

    legend_handles = [
        mpatches.Patch(facecolor=node_styles["subjects"]['color'],
                       edgecolor=node_styles["subjects"]['ec'],
                       label='Subjects'),
        mpatches.Patch(facecolor=node_styles["predicates"]['color'],
                       edgecolor=node_styles["predicates"]['ec'],
                       label='Predicates'),
        mpatches.Patch(facecolor=node_styles["objects"]['color'],
                       edgecolor=node_styles["objects"]['ec'],
                       label='Objects'),
    ]
    plt.legend(handles=legend_handles,
               loc='upper right',
               title='Node Types',
               framealpha=0.9)

    plt.title('Enhanced Knowledge Graph Visualization', fontsize=18)
    plt.axis('off')
    plt.tight_layout(pad=4.0)
    plt.savefig("KF_advanced.png", dpi=300)
    plt.show()

visualize_single_graph(graph)

# %% [markdown]
# Let's use the power of SPARQL in SAP HANA

# %% [markdown]
# #### **Important Setup:**  .env File Required for HANA Cloud Access
#
# Before running the application, ensure that the `.env` file is present in the same directory as the source code. This file contains the necessary credentials for accessing HANA Cloud.
#
# The `.env` file should include the following lines with the appropriate values:
#
#
# > hana_address="xxxxx.hanacloud.ondemand.com"
# > hana_port= "443"
# > hana_user="xxxxx"
# > hana_password="xxxxxx"
# > hana_encrypt="default"
#
#
# #### **Make sure to replace the placeholders (`xxxxxxx`) with your actual HANA Cloud credentials.**

# %%
from hdbcli import dbapi
import os
import json
import numpy as np

# Connection parameters
HANA_ADDRESS = os.getenv("hana_address")
HANA_PORT = os.getenv("hana_port")
HANA_USER = os.getenv("hana_user")
HANA_PASSWORD = os.getenv("hana_password")
GRAPH_NAME = "product_KG_pdf2"


# Functions for converting values to IRIs and literals
def to_iri(value: str, base: str = "http://example.com/") -> str:
    import re
    encoded_part = re.sub(
        r"[^a-zA-Z0-9\\-_\\.]", lambda m: f"%{ord(m.group(0)):02X}", value
    )
    return f"<{base}{encoded_part}>"

def to_literal(value: str) -> str:
    if value is None:
        return '""'
    escaped = (
        value.replace("\\", "\\\\")
        .replace('"', '\\"')
        .replace("\n", "\\n")
        .replace("\r", "\\r")
    )
    return f'"{escaped}"'

# %% [markdown]
# #### Prefixes in SAP HANA SPARQL
#
# In this example, we used <http://example.com/> as the base URI, but you can choose any other. See more about prefixes below.
#
# **What is an IRI?**
# An IRI is an extended URI that allows unique identification of resources (subjects, predicates, and objects) in distributed systems.
#
# **Example of a full IRI:**
# <http://example.com/resource/CompressorMotor123>
#
# **What is a prefix?**
# A prefix is a short alias for a long IRI — it makes writing and reading queries easier.
#
# **Choosing your prefix:**
# Name it according to the task (e.g. `motor:`, `sensor:`, `device:`) and use it consistently.
#
# **Why do you need prefixes:**
# - Reduce the amount of code
# - Improve readability
# - Make it easier to change the base URI
#
# **When to include public ontologies:**
# For standard terms and metadata (RDF, RDFS, schema.org, FOAF, Dublin Core) — to ensure semantic compatibility.
#
# For standard terms and metadata (RDF, RDFS, schema.org, FOAF, Dublin Core) — to ensure semantic compatibility.
#
#
# ```sparql
# PREFIX rdf:   <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs:  <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX schema: <http://schema.org/>
# PREFIX foaf:  <http://xmlns.com/foaf/0.1/>
# PREFIX dc:    <http://purl.org/dc/elements/1.1/>
# ```
#
# For more details on the PREFIX clause in SAP HANA SPARQL, see:
#
# https://help.sap.com/docs/hana-cloud-database/sap-hana-cloud-sap-hana-database-sparql-reference-guide/prefix-clause?locale=en-US

# %%
# Connecting to SAP HANA
conn = dbapi.connect(
    address=HANA_ADDRESS, port=HANA_PORT, user=HANA_USER, password=HANA_PASSWORD
)
cursor = conn.cursor()

# Defining IRI for graph
graph_iri = to_iri(GRAPH_NAME, base="http://graph/")

# Bulk insertion of graph data
print("[INFO] Inserting data into the graph...")

# LangChain returns triples as (subject, object, predicate)
triples_statements = []
for subj, obj, pred in triples:
    subj_iri = to_iri(subj, base="http://example.com/resource/")
    pred_iri = to_iri(pred, base="http://example.com/property/")
    obj_literal = to_literal(obj)
    triples_statements.append(f"    {subj_iri} {pred_iri} {obj_literal} .")

sparql_bulk_insert = f"""
INSERT DATA {{
  GRAPH {graph_iri} {{
{chr(10).join(triples_statements)}
  }}
}}
""".strip()

try:
    cursor.callproc("SPARQL_EXECUTE", [sparql_bulk_insert, "", None, None])
    print(f"[INFO] Bulk insert of {len(triples)} triples successful.")
except Exception as e:
    print(f"[ERROR] Bulk insert failed: {e}")
    print(f"[ERROR] Query:\n{sparql_bulk_insert}")

conn.commit()
# Out:
# [INFO] Inserting data into the graph...
# [INFO] Bulk insert of 147 triples successful.

# %%
from hdbcli import dbapi
import os

# Form and execute a SPARQL query
sparql_query = f"""
SELECT DISTINCT ?s ?p ?o
FROM {graph_iri}
WHERE {{
  # ?s ?p ?o
}}
"""

print("[INFO] Executing SPARQL SELECT query...")
try:
    cursor.execute(f"SELECT * FROM SPARQL_TABLE('{sparql_query}')")
    results = cursor.fetchall()
    if results:
        print("[RESULT] Query results:")
        for row in results:
            # usualy row = (subject, predicate, object)
            print(row)
    else:
        print("[RESULT] No data found.")
except Exception as e:
    print(f"[ERROR] SPARQL SELECT query failed: {e}")

# Closing the connection
cursor.close()
# Out:
# [INFO] Executing SPARQL SELECT query...
# [RESULT] Query results:
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20equipped%20with', 'bearing temperature sensors (RTDs)')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20equipped%20with', 'space heaters')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20temperature%20rating', 'Class B temperature rise')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20temperature%20rating', 'maximum temperature rise 80°C @ 1.0 SF and 90°C @ 1.15 SF')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'Babbitted sleeve bearings with splash lubrication')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'all control wiring terminated in spade-type terminations')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'auxiliary terminal boxes constructed of pressed steel sheets')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'compatible with existing monitoring and control devices at motor controller')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'dynamic balancing per NEMA MG 1 Part 7')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'instrumentation terminal box in same location as existing')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'main power leads protected by fabricated steel or cast-iron')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'noise level measured per IEEE 85 at 3 feet from major motor surfaces')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'sealed insulation system meeting NEMA MG 1 2.27.2')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stainless steel screens and air filters')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'terminations rated for 105°C')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'vibration readings measured and recorded at upper and lower bearing housings during full load testing')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'warranty period of two years following acceptance by District')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20protection%20rating', 'UL and CSA approval required')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/operates%20at%20voltage', '4160V')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'IEEE 43')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ISO 1940/1')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'full load current 180A')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'locked rotor current at 4160V required')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'transient reactance 0.140 pu')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20insulation%20class', 'Class F insulation')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20speed%20rating', '3600 RPM')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20power%20rating', '1500 HP')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'space heaters')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'Babbitted sleeve bearings with splash lubrication')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'bearing temperature sensors (RTDs)')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'space heaters')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'Babbitted sleeve bearings with splash lubrication')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'bearing temperature sensors (RTDs)')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'space heaters')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20protection%20rating', 'IP rating per NEMA WP I')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20protection%20rating', 'IP rating per NEMA WP I')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/operates%20at%20voltage', '4160V')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/operates%20at%20voltage', '4160V')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/operates%20at%20voltage', '4160V')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 43')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE Std 112')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 43')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE Std 112')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 43')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE Std 112')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20load%20characteristic', 'full load current 180A')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20load%20characteristic', 'minimum 2 consecutive starts with motor coasting to rest between starts')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20load%20characteristic', 'full load current 180A')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20load%20characteristic', 'minimum 2 consecutive starts with motor coasting to rest between starts')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/is%20replacement%20for', 'Main Air Compressor Motor at Plant 1')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20speed%20rating', '3600 RPM')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20speed%20rating', '3600 RPM')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20speed%20rating', '3600 RPM')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20power%20rating', '1500 HP')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20power%20rating', '1500 HP')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20temperature%20rating', 'ambient temperature 40°C maximum')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'all control wires marked with slip-on sleeve-type wire markers')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'all windings and bearing temperature measurements made using permanently installed detectors')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'copper bus work fully insulated and supported with epoxy insulators')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'extended rear shaft for main oil lube pump')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'factory noise test required')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'filter housing removable')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'heaters maintain winding temperature 10°C above ambient during de-energized conditions')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'main power lead conductors exit at same location as existing')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'manufacturer to provide three certified copies of factory test reports to District')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'motor shaft run-out less than 0.002 inch')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'non-hygroscopic insulation system')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'severe duty marine grade ANSI 61 gray paint finish')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stainless steel nameplate per NEMA MG 1-20.60')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stainless steel nameplate with NEMA MG 1-20.60 information')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stator core built-up from low loss high permeability steel laminations')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'vibration readings not to exceed 0.10 in/sec peak')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20a', 'Equipment')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ANSI standards')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ASTM E125-63')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ASTM E709-21')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'IEEE 112')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'IEEE 85')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'NEC')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'NEMA MG 1-2006')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'UL')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'can accelerate load to full speed within 25 seconds at 65% voltage')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'driven load inertia (WR2) at start 520 lb-ft2')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'duty: continuous 90°C @ 1.15 SF')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'full load torque 2188 ft-lb')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'full-load amperes at 4160V required')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'minimum locked rotor torque 2150 ft-lb')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'rated torque at design speed 2188 ft. lb.')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20insulation%20class', 'Class F insulation with Class B temperature rise')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20bearing', 'Babbitted sleeve bearings')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20frame', '6809-H')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20protection%20rating', 'WPI enclosure')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/is%20a', 'Equipment')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/is%20a', 'Equipment')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/is%20a', 'Equipment')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 112')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 85')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'NEC')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'UL')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 85')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'NEC')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 85')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'NEC')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20load%20characteristic', 'minimum 3 evenly spaced starts in first hour prior to continuous running')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20load%20characteristic', 'minimum locked rotor torque 2150 ft-lb')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20equipped%20with', 'RTDs for winding temperature detection')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20equipped%20with', 'main and auxiliary terminal boxes')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20equipped%20with', 'vibration sensors')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20equipped%20with', 'winding temperature sensors (RTDs)')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20temperature%20rating', 'ambient temperature 40°C')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', '1/4-28 tap on each bearing housing for tri-axial accelerometer-type vibration sensors')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'auxiliary terminal boxes for stator RTD and space heater leads')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'copper or copper alloy rotor bars and end rings')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'four bearing RTDs (two per front and rear bearing)')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'horizontal foot mounted configuration')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'main power leads protected by fabricated steel or cast-iron construction')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'main power leads sufficient length for termination in separate box')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'medium voltage bus work copper with plated joints')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stator RTDs embedded in winding slots per NEMA MG 1-20.63')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stator coils braced and supported by carbon steel insulated rings')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stator insulation system highly moisture and chemical resistant')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'two stainless steel grounding pads')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'vibration readings measured at upper and lower bearing housings')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20protection%20rating', 'NEMA WP I enclosure')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ANSI')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ASTM A345-19')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'ASTM A536-84')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'CSA')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'IEEE 522')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'NEC standards')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'NEMA MG 1')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'locked rotor current 6.3 or less x FLA')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'minimum breakaway torque at 2413 volts 600 ft-lb')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'minimum locked rotor torque 2150 ft. lb.')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'service factor 1.15 @ 105°C')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20bearing', 'two end shield supported Babbitted sleeve bearings')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20enclosure', 'NEMA WP I')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'RTDs for winding temperature detection')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'vibration sensors')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'RTDs for winding temperature detection')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'vibration sensors')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20protection%20rating', 'NEMA WP I enclosure')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20protection%20rating', 'NEMA WP I enclosure')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'CSA')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 522')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'NEMA 250')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'NEMA MG 1')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'CSA')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 522')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'NEMA 250')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'NEMA MG 1')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20speed%20rating', '3574 RPM')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20speed%20rating', '3574 RPM')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20power%20rating', '1250 HP')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20power%20rating', '1250 HP')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20manufacturer', 'Westinghouse')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20manufacturer', 'Westinghouse')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20model', 'HSW-1')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20model', 'HSW-1')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'RTDs for winding temperature detection')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'vibration sensors')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'auxiliary terminal boxes for stator RTD and space heater leads')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'stainless steel nameplate')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'vibration sensors')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20equipped%20with', 'RTDs for bearing temperature detection')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'all cable terminations made using stress cones')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'compatible with autotransformer type motor starters')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'factory noise test required during performance test')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'heaters to maintain winding temperature 10°C above ambient')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'main oil pump driven by motor shaft')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'manufacturer to provide qualified field technician for installation and startup')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'motor not to be shipped until District has approved factory test reports')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'motor shaft extension to drive main oil lube pump')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'sealed insulation system impervious to contaminants')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'severe duty marine grade ANSI 61 gray paint')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stator RTDs: twelve (four per phase)')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stator core capable of withstanding winding burn-out temperatures of 1000°F')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stator core lamination plate at least C-5 or C-6 quality per ASTM A345')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'stator leads with oil resistant material such as PVC')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'two stainless steel grounding pads diagonally apart on each side of frame')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'two stainless steel grounding pads diagonally apart on each side of the motor frame')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/is%20designed%20with', 'vacuum pressure impregnation process for coils')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20protection%20rating', 'Weather-Protected I (WP-I)')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20industry%20standard', 'API 541')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'accelerate load to full speed within 25 seconds or less at 65% tap')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'locked rotor KVA code G')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'minimum breakaway torque at 2413 volts 600 ft. lb.')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'no-load amperes at 4160V required')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'noise level determined per IEEE 85')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'power factor 0.936 or higher')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'slip and full-load rpm data required')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'speed vs. torque and current curves at 4160V required')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'starting method reduced voltage autotransformer')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/has%20load%20characteristic', 'starting method: reduced voltage autotransformer')
# ('http://example.com/resource/1500%2DHP%20Main%20Air%20Compressor%20Motor', 'http://example.com/property/operates%20at%20frequency', '60Hz')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'RTDs for bearing temperature detection')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'RTDs for bearing temperature detection')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'API 541')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'API 541')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/operates%20at%20frequency', '60Hz')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/operates%20at%20frequency', '60Hz')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'RTDs for bearing temperature detection')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'main oil pump driven by motor shaft')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'main oil pump driven by motor shaft')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20temperature%20rating', '40°C ambient temperature')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20temperature%20rating', '40°C ambient temperature')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'API 541')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'API 541')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'API 541')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20load%20characteristic', 'power factor 0.936 or higher')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20load%20characteristic', 'starting method reduced voltage autotransformer')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20load%20characteristic', 'power factor 0.936 or higher')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20load%20characteristic', 'starting method reduced voltage autotransformer')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/operates%20at%20frequency', '60Hz')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/operates%20at%20frequency', '60Hz')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/operates%20at%20frequency', '60Hz')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20bearing', 'two end shield supported bearings')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'winding temperature sensors (RTDs)')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'auxiliary terminal boxes for stator RTD and space heater leads')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'stainless steel nameplate')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'vibration sensors')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'winding temperature sensors (RTDs)')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20protection%20rating', 'NEMA WP I enclosure')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20protection%20rating', 'NEMA WP I enclosure')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20protection%20rating', 'NEMA WP I enclosure')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'CSA')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 522')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'NEMA 250')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'NEMA MG 1')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'ANSI')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 522')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'NEMA MG 1')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'ANSI')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 522')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'NEMA MG 1')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20load%20characteristic', 'can accelerate load to full speed within 25 seconds at 65% tap')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20load%20characteristic', 'locked rotor current 6.3 x FLA or less')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20load%20characteristic', 'minimum 3 consecutive starts with 2-second jogging 10 seconds apart')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20load%20characteristic', 'rated torque at design speed 2188 ft-lb')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20load%20characteristic', 'service factor 1.15 @ 105°C')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20load%20characteristic', 'can accelerate load to full speed within 25 seconds at 65% tap')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20load%20characteristic', 'locked rotor current 6.3 x FLA or less')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20load%20characteristic', 'minimum 3 consecutive starts with 2-second jogging 10 seconds apart')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20load%20characteristic', 'rated torque at design speed 2188 ft-lb')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20load%20characteristic', 'service factor 1.15 @ 105°C')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20speed%20rating', '3574 RPM')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20power%20rating', '1250 HP')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20bearing', 'Babbitted sleeve bearing')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20bearing', 'sight glasses with fill and drain ports')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20bearing', 'Babbitted sleeve bearing')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20bearing', 'sight glasses with fill and drain ports')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20manufacturer', 'Westinghouse')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20manufacturer', 'TECO-Westinghouse or Nidec or Toshiba or WEG or General Electric or approved equal')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20manufacturer', 'TECO-Westinghouse or Nidec or Toshiba or WEG or General Electric or approved equal')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20model', 'HSW-1')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'RTDs for winding temperature detection')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'vibration sensors')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'auxiliary terminal boxes for stator RTD and space heater leads')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'stainless steel nameplate')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'vibration sensors')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'winding temperature sensors (RTDs)')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'auxiliary terminal boxes for stator RTD and space heater leads')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'stainless steel nameplate')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'vibration sensors')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'winding temperature sensors (RTDs)')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20protection%20rating', 'NEMA WP I enclosure')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20protection%20rating', 'NEMA WP I enclosure')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20protection%20rating', 'NEMA WP I enclosure')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'CSA')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 522')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'NEMA 250')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'NEMA MG 1')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'ANSI')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 522')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'NEMA MG 1')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20power%20rating', '1500 HP')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20style', 'T4F18238')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'space heaters')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/is%20equipped%20with', 'space heaters')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/operates%20at%20voltage', '4160V')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/operates%20at%20voltage', '4160V')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 43')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE Std 112')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 43')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE Std 112')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/is%20replacement%20for', 'Main Air Compressor Motor at Plant 1')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20speed%20rating', '3600 RPM')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20speed%20rating', '3600 RPM')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20power%20rating', '1500 HP')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20power%20rating', '1500 HP')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20style', 'T4F18238')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20style', 'T4F18238')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'space heaters')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'Babbitted sleeve bearings with splash lubrication')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'bearing temperature sensors (RTDs)')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'space heaters')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'Babbitted sleeve bearings with splash lubrication')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'bearing temperature sensors (RTDs)')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'space heaters')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20protection%20rating', 'IP rating per NEMA WP I')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20protection%20rating', 'IP rating per NEMA WP I')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/operates%20at%20voltage', '4160V')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/operates%20at%20voltage', '4160V')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/operates%20at%20voltage', '4160V')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 43')
# ...
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE Std 112')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 43')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE Std 112')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20load%20characteristic', 'full load current 180A')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20load%20characteristic', 'minimum 2 consecutive starts with motor coasting to rest between starts')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20load%20characteristic', 'full load current 180A')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20load%20characteristic', 'minimum 2 consecutive starts with motor coasting to rest between starts')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20speed%20rating', '3600 RPM')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20speed%20rating', '3600 RPM')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20speed%20rating', '3600 RPM')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20power%20rating', '1500 HP')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20power%20rating', '1500 HP')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20power%20rating', '1500 HP')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20style', 'T4F18238')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20load%20characteristic', 'minimum 3 evenly spaced starts in first hour prior to continuous running')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20load%20characteristic', 'minimum locked rotor torque 2150 ft-lb')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20insulation%20class', 'Class F insulation with Class B temperature rise')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20insulation%20class', 'Class F insulation with Class B temperature rise')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20insulation%20class', 'Class F insulation with Class B temperature rise')
# ('http://example.com/resource/MAC%201%2D1', 'http://example.com/property/has%20frame', '6809-H')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20protection%20rating', 'WPI enclosure')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20protection%20rating', 'WPI enclosure')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/is%20a', 'Equipment')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/is%20a', 'Equipment')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 112')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 85')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'NEC')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'UL')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 112')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 85')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'NEC')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20industry%20standard', 'UL')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20insulation%20class', 'Class F insulation with Class B temperature rise')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20insulation%20class', 'Class F insulation with Class B temperature rise')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/is%20replacement%20for', 'Main Air Compressor Motor at Plant 2')
# ('http://example.com/resource/MAC%201%2D2', 'http://example.com/property/has%20frame', '6809-H')
# ('http://example.com/resource/MAC%202%2D2', 'http://example.com/property/has%20frame', '6809-H')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20protection%20rating', 'WPI enclosure')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/is%20a', 'Equipment')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/is%20a', 'Equipment')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/is%20a', 'Equipment')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 112')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 85')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'NEC')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'UL')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'IEEE 85')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'NEC')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 85')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'NEC')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20efficiency%20rating', '95% or higher at 100% load')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20load%20characteristic', 'minimum 3 evenly spaced starts in first hour prior to continuous running')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20load%20characteristic', 'minimum locked rotor torque 2150 ft-lb')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20load%20characteristic', 'minimum 3 evenly spaced starts in first hour prior to continuous running')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20load%20characteristic', 'minimum locked rotor torque 2150 ft-lb')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20insulation%20class', 'Class F insulation with Class B temperature rise')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20insulation%20class', 'Class F insulation with Class B temperature rise')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20insulation%20class', 'Class F insulation with Class B temperature rise')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/is%20replacement%20for', 'Main Air Compressor Motor at Plant 2')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20frame', '6809-H')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'ANSI')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'IEEE 522')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'NEMA MG 1')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20load%20characteristic', 'can accelerate load to full speed within 25 seconds at 65% tap')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20load%20characteristic', 'locked rotor current 6.3 x FLA or less')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20load%20characteristic', 'minimum 3 consecutive starts with 2-second jogging 10 seconds apart')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20load%20characteristic', 'rated torque at design speed 2188 ft-lb')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20load%20characteristic', 'service factor 1.15 @ 105°C')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20load%20characteristic', 'can accelerate load to full speed within 25 seconds at 65% tap')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20load%20characteristic', 'locked rotor current 6.3 x FLA or less')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20load%20characteristic', 'minimum 3 consecutive starts with 2-second jogging 10 seconds apart')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20load%20characteristic', 'rated torque at design speed 2188 ft-lb')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20load%20characteristic', 'service factor 1.15 @ 105°C')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20speed%20rating', '3574 RPM')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20power%20rating', '1250 HP')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20bearing', 'Babbitted sleeve bearing')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20bearing', 'sight glasses with fill and drain ports')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20bearing', 'Babbitted sleeve bearing')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20bearing', 'sight glasses with fill and drain ports')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20manufacturer', 'Westinghouse')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20manufacturer', 'TECO-Westinghouse or Nidec or Toshiba or WEG or General Electric or approved equal')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20manufacturer', 'TECO-Westinghouse or Nidec or Toshiba or WEG or General Electric or approved equal')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20model', 'HSW-1')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20bearing', 'two end shield supported bearings')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'http://example.com/property/has%20enclosure', 'Weather-Protected I (WPI)')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'http://example.com/property/has%20enclosure', 'Weather-Protected I (WPI)')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/is%20equipped%20with', 'RTDs for bearing temperature detection')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/is%20equipped%20with', 'main oil pump driven by motor shaft')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/is%20equipped%20with', 'main oil pump driven by motor shaft')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20temperature%20rating', '40°C ambient temperature')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20temperature%20rating', '40°C ambient temperature')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/has%20industry%20standard', 'API 541')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20industry%20standard', 'API 541')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20industry%20standard', 'API 541')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20load%20characteristic', 'power factor 0.936 or higher')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20load%20characteristic', 'starting method reduced voltage autotransformer')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20load%20characteristic', 'power factor 0.936 or higher')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20load%20characteristic', 'starting method reduced voltage autotransformer')
# ('http://example.com/resource/MAC%202%2D1', 'http://example.com/property/operates%20at%20frequency', '60Hz')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/operates%20at%20frequency', '60Hz')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/operates%20at%20frequency', '60Hz')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20bearing', 'two end shield supported bearings')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20bearing', 'two end shield supported bearings')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'http://example.com/property/has%20enclosure', 'Weather-Protected I (WPI)')
# ('http://example.com/resource/Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'http://example.com/property/has%20enclosure', 'Weather-Protected I (WPI)')

# %% [markdown]
# ### Let's put everything together into one set of functions to demonstrate how the KG query pipeline works

# %% [markdown]
# ### Function Reference: SAP HANA Knowledge Graph Pipeline
#
# Below you will find a summary of the main utility functions for building and querying a knowledge graph in SAP HANA using PDF extraction, LLMs, and SPARQL.
#
# #### `connect_hana(hana_env, dbapi)`
# Opens a connection to SAP HANA and returns the connection and cursor objects for use in subsequent queries and inserts.
#
# #### `close_hana(conn, cursor)`
# Closes the SAP HANA database cursor and connection, ensuring resources are released after each operation.
#
# #### `extract_and_store_kg_from_pdf(pdf_filename, GRAPH_NAME, KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT, chat_llm, dbapi, to_iri, to_literal, hana_env)`
# Reads a PDF file, extracts triples from its text using a large language model (LLM), and writes all triples to a specified knowledge graph in SAP HANA via a bulk SPARQL insert.
#
# #### `get_unique_relations(GRAPH_NAME, dbapi, hana_env)`
# Returns a list of all unique relation names (i.e., object values) present in the specified knowledge graph. Useful for understanding which kinds of facts are represented.
#
# #### `get_triples_by_relations(GRAPH_NAME, relation_list, dbapi, hana_env)`
# Retrieves all triples from the knowledge graph where the object (relation) matches any value in `relation_list`. This allows targeted extraction of facts relevant to specific business attributes.
#
# #### `clear_kg_graph(GRAPH_NAME, dbapi, hana_env)`
# Deletes all triples from the named graph in SAP HANA, effectively resetting the graph for a new extraction or test.
#
# ---
#
# > These functions are designed to streamline the end-to-end workflow: loading data from documents, structuring it with LLM extraction, storing it in a graph database, and enabling efficient queries and graph maintenance.

# %%
# -- Connection helpers --
def connect_hana(hana_env, dbapi):
    """
    Opens a connection to SAP HANA and returns (conn, cursor).
    """
    conn = dbapi.connect(
        address=hana_env['hana_address'],
        port=hana_env['hana_port'],
        user=hana_env['hana_user'],
        password=hana_env['hana_password']
    )
    cursor = conn.cursor()
    return conn, cursor


def close_hana(conn, cursor):
    """
    Closes the SAP HANA cursor and connection.
    """
    cursor.close()
    conn.close()

def extract_and_store_kg_from_pdf(pdf_filename, GRAPH_NAME, KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT, chat_llm, dbapi, to_iri, to_literal, hana_env):
    """
    Reads a PDF, extracts triples via LLM, and bulk writes them to KG in SAP HANA.
    Returns the list of triples.
    """
    from langchain_community.document_loaders import PyPDFLoader
    from langchain.indexes.graph import GraphIndexCreator

    loader = PyPDFLoader(pdf_filename)
    docs = loader.load()
    doc_content = 'This is a compressor specification: '
    for doc in docs:
        doc_content += ' ' + doc.page_content

    index_creator = GraphIndexCreator(llm=chat_llm)
    graph = index_creator.from_text(text=doc_content, prompt=KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT)
    triples = graph.get_triples()

    conn, cursor = connect_hana(hana_env, dbapi)
    graph_iri = to_iri(GRAPH_NAME, base="http://graph/")

    print("[INFO] Inserting data into the graph...")
    triples_statements = []

    # LangChain returns triples as (subject, object, predicate)
    for subj, obj, pred in triples:
        subj_iri = to_iri(subj, base="http://example.com/resource/")
        pred_iri = to_iri(pred, base="http://example.com/property/")
        obj_literal = to_literal(obj)
        triples_statements.append(f"    {subj_iri} {pred_iri} {obj_literal} .")

    sparql_bulk_insert = f"""
    INSERT DATA {{
      GRAPH {graph_iri} {{
{chr(10).join(triples_statements)}
      }}
    }}
    """.strip()

    try:
        cursor.callproc("SPARQL_EXECUTE", [sparql_bulk_insert, "", None, None])
        print(f"[INFO] Bulk insert of {len(triples)} triples successful.")
    except Exception as e:
        print(f"[ERROR] Bulk insert failed: {e}")
        print(f"[ERROR] Query:\n{sparql_bulk_insert}")

    conn.commit()
    close_hana(conn, cursor)
    return triples

def get_unique_relations(GRAPH_NAME, dbapi, hana_env):
    """
    Returns all unique predicate names from the specified KG.
    """
    from urllib.parse import unquote

    conn, cursor = connect_hana(hana_env, dbapi)
    graph_iri = f"<http://graph/{GRAPH_NAME}>"
    unique_relations = set()

    sparql_query = f"""
    SELECT "p"
    FROM SPARQL_TABLE(
      'SELECT DISTINCT ?p
       FROM {graph_iri}
       WHERE {{ ?s ?p ?o }}'
    ) AS "result"
    """

    try:
        cursor.execute(sparql_query)
        results = cursor.fetchall()
        for row in results:
            if row and row[0]:
                pred = str(row[0]).strip("<>")
                pred = pred.replace("http://example.com/property/", "")
                pred = unquote(pred)   # <-- ключевая правка
                unique_relations.add(pred)
    except Exception as e:
        print(f"[ERROR] Failed to retrieve relations: {e}")

    close_hana(conn, cursor)
    return list(unique_relations)

def get_triples_by_relations(GRAPH_NAME, relation_list, dbapi, hana_env):
    """
    Returns all triples in the graph with predicate matching any in relation_list.
    """
    from urllib.parse import unquote

    if not relation_list:
        return []

    conn, cursor = connect_hana(hana_env, dbapi)
    graph_iri = f"<http://graph/{GRAPH_NAME}>"

    normalized_relations = [unquote(rel) for rel in relation_list]

    pred_conditions = " || ".join(
        [f'?p = {to_iri(rel, base="http://example.com/property/")}' for rel in normalized_relations]
    )

    sparql_query = f"""
    SELECT "s", "p", "o"
    FROM SPARQL_TABLE(
      'SELECT ?s ?p ?o
       FROM {graph_iri}
       WHERE {{
         # ?s ?p ?o .
         FILTER({pred_conditions})
       }}'
    ) AS "result"
    """

    triples = []
    try:
        cursor.execute(sparql_query)
        results = cursor.fetchall()
        for row in results:
            subj = str(row[0]).strip("<>").replace("http://example.com/resource/", "")
            pred = str(row[1]).strip("<>").replace("http://example.com/property/", "")
            pred = unquote(pred)
            obj = str(row[2]).strip('"')
            triples.append((subj, pred, obj))
    except Exception as e:
        print(f"[ERROR] Failed to retrieve triples: {e}")

    close_hana(conn, cursor)
    return triples


def clear_kg_graph(GRAPH_NAME, dbapi, hana_env):
    """
    Deletes all triples from the specified named graph in SAP HANA.
    """
    conn, cursor = connect_hana(hana_env, dbapi)
    graph_iri = f"<http://graph/{GRAPH_NAME}>"
    sparql_delete = f"CLEAR GRAPH {graph_iri}"
    try:
        cursor.callproc("SPARQL_EXECUTE", [sparql_delete, "", None, None])
        print(f"[INFO] Graph {GRAPH_NAME} cleared successfully.")
    except Exception as e:
        print(f"[ERROR] Failed to clear graph: {e}")
        print(f"[ERROR] Query:\n{sparql_delete}")
    close_hana(conn, cursor)


# -- Usage example --
hana_env = {
    'hana_address': HANA_ADDRESS,
    'hana_port': HANA_PORT,
    'hana_user': HANA_USER,
    'hana_password': HANA_PASSWORD,
}


GRAPH_NAME = "KG_pdf_tmp_01"

# 0. Extract triples and store in KG
triples = extract_and_store_kg_from_pdf(
    pdf_filename="2312_-_Four_1500-HP_Main_Air_Compressor_Motors_FINAL.pdf",
    GRAPH_NAME=GRAPH_NAME,
    KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT=KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT,
    chat_llm=chat_llm,
    dbapi=dbapi,
    to_iri=to_iri,
    to_literal=to_literal,
    hana_env=hana_env
)


# Testing functions:

# 1. Get all unique relation names (object values) in the graph
relations = get_unique_relations(GRAPH_NAME, dbapi, hana_env)
print("Unique relations:", relations)

# 2. Get all triples for a list of relations (object values)
relation_list = [
    "has efficiency rating",
    "operates at voltage"
]
triples_filtered = get_triples_by_relations(GRAPH_NAME, relation_list, dbapi, hana_env)
for t in triples_filtered:
    print("Triple:", t)

# 3. Clear all triples in a named graph
clear_kg_graph(GRAPH_NAME, dbapi, hana_env)
# Out:
# [INFO] Inserting data into the graph...
# [INFO] Bulk insert of 148 triples successful.
# Unique relations: ['operates at frequency', 'has protection rating', 'has bearing', 'has speed rating', 'is designed with', 'has insulation class', 'is equipped with', 'has industry standard', 'has load characteristic', 'has efficiency rating', 'has temperature rating', 'operates at voltage', 'has power rating', 'is a', 'has manufacturer', 'has enclosure']
# Triple: ('Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'operates at voltage', '4160V')
# Triple: ('Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'operates at voltage', '4160V')
# Triple: ('Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'operates at voltage', '4160V')
# Triple: ('Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'operates at voltage', '4160V')
# Triple: ('Main%20Air%20Compressor%20Motor%20MAC%202%2D1', 'has efficiency rating', '95% or higher at 100% load')
# Triple: ('Main%20Air%20Compressor%20Motor%20MAC%202%2D2', 'has efficiency rating', '95% or higher at 100% load')
# Triple: ('Main%20Air%20Compressor%20Motor%20MAC%201%2D1', 'has efficiency rating', '95% or higher at 100% load')
# Triple: ('Main%20Air%20Compressor%20Motor%20MAC%201%2D2', 'has efficiency rating', '95% or higher at 100% load')
# [INFO] Graph KG_pdf_tmp_01 cleared successfully.

# %% [markdown]
# ### `ask_llm_simple(prompt: str) -> str`
# Sends a prompt string to a Large Language Model (LLM) and returns the generated response as a string.

# %%
def ask_llm_simple(prompt: str) -> str:
   try:
       llm = ChatOpenAI(proxy_model_name='gpt-4o', proxy_client=proxy_client)
       result = llm.invoke(prompt)
       return result.content
   except Exception as e:
       print(f"⚠️ LLM Call Error: {e} | Prompt (first 100 chars): {prompt[:100]!r}")
       raise

print(ask_llm_simple("1+1"))
# Out:
# 1 + 1 = 2

# %% [markdown]
# ### `filter_relations_by_business_question(relations, business_question, ask_llm_simple)`
#
# Given a list of property (relation) names from the knowledge graph and a business question in plain English, this function uses a Large Language Model (LLM) to select only those relations that are relevant for answering the question.

# %%
import re
import ast

def filter_relations_by_business_question(relations, business_question, ask_llm_simple):
    """
    Filters a list of property names, returning only those that are relevant to the user's natural language business question.
    
    :param relations: List of all property/relation names from the knowledge graph.
    :param business_question: A natural language business question or task (e.g., 'Compare energy efficiency').
    :param ask_llm_simple: Function to call LLM with a prompt and get a response.
    :return: List of relations the LLM judges as relevant.
    """
    prompt = (
        "You are helping to analyze business data using a knowledge graph.\n"
        f"Here is a list of property names from the knowledge graph:\n{relations}\n"
        f"The user asks: \"{business_question}\"\n"
        "From the list above, select ONLY the properties that are directly relevant to answering or summarizing this user's question.\n"
        "Return a Python list with only the relevant property names, with no explanation."
    )
    response = ask_llm_simple(prompt).strip()
    import re, ast
    # Try to extract the first Python list from the response
    list_match = re.search(r'(\[[^\]]*\])', response)
    if not list_match:
        # Try assignment style: something = [...]
        assign_match = re.search(r'=\s*(\[[^\]]*\])', response)
        if assign_match:
            list_str = assign_match.group(1)
        else:
            print("[WARN] LLM response did not contain a Python list:", response)
            return []
    else:
        list_str = list_match.group(1)
    try:
        filtered = ast.literal_eval(list_str)
        if isinstance(filtered, list):
            return [x for x in filtered if x in relations]
    except Exception as e:
        print("[WARN] Could not parse list from LLM response:", list_str)
    return []

# Example usage:
relations = [
    "is a", "has efficiency rating", "has insulation class", "has power rating",
    "has load characteristic", "has speed rating", "operates at voltage",
    "operates at frequency", "has manufacturer", "has frame", "has enclosure"
]
business_question = "Summarize the energy efficiency of this motor"
relevant = filter_relations_by_business_question(relations, business_question, ask_llm_simple)
print("Relevant relations:", relevant)
# Out:
# Relevant relations: ['has efficiency rating', 'has insulation class', 'has power rating']

# %% [markdown]
# ## Graph RAG

# %% [markdown]
# ### Scenario 1
#
# In this example, a procurement expert receives a PDF document with the technical specifications for an industrial motor. Instead of searching manually through the document for important details, the engineer uses an automated system to extract a structured knowledge graph from the PDF. Next, the engineer asks a business question such as, “Summarize the energy efficiency of this motor.” The system automatically determines which characteristics in the knowledge graph are relevant for energy efficiency, retrieves those facts, and uses a language model (LLM) to generate a short, clear summary in response to the question. This way, the engineer quickly gets exactly the information needed, saving time and avoiding manual work.

# %%
business_question = "Summarize the energy efficiency of this motor."
pdf_filename = "A700000006779737.pdf"         # your PDF file with equipment spec
GRAPH_NAME = "KG_pdf_demo_01"

# 1. Extract triples from the PDF and store them in SAP HANA KG
triples = extract_and_store_kg_from_pdf(
    pdf_filename=pdf_filename,
    GRAPH_NAME=GRAPH_NAME,
    KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT=KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT,
    chat_llm=chat_llm,
    dbapi=dbapi,
    to_iri=to_iri,
    to_literal=to_literal,
    hana_env=hana_env
)

# 2. Get all property/relation names present in the new KG
relations = get_unique_relations(GRAPH_NAME, dbapi, hana_env)
print("All relations found in KG:", relations)

# 3. Use the LLM to filter only those relations that are relevant for the business question
relevant_relations = filter_relations_by_business_question(relations, business_question, ask_llm_simple)
print("Relevant relations for the question:", relevant_relations)

# 4. Retrieve only the triples that match the relevant relations
triples_for_summary = get_triples_by_relations(GRAPH_NAME, relevant_relations, dbapi, hana_env)
print("Triples selected for summary:", triples_for_summary)

# 5. Build a summary with the LLM using only the relevant triples
if triples_for_summary:
    # Create a prompt with the selected triples
    summary_prompt = (
        f"You are an equipment expert. Given the following technical facts:\n"
        f"{triples_for_summary}\n"
        f"Please provide a concise summary that answers this question: {business_question}\n"
    )
    summary = ask_llm_simple(summary_prompt)
    print("=" * 60)
    print("Summary:\n", summary)
    print("=" * 60)
else:
    print("No relevant facts found for this question in the current knowledge graph.")

# 6. (Optional) Clean up graph after demo
clear_kg_graph(GRAPH_NAME, dbapi, hana_env)
# Out:
# [INFO] Inserting data into the graph...
# [INFO] Bulk insert of 30 triples successful.
# All relations found in KG: ['operates at frequency', 'has protection rating', 'is designed with', 'has insulation class', 'is equipped with', 'has industry standard', 'has load characteristic', 'has efficiency rating', 'has temperature rating', 'operates at voltage', 'is a', 'has power rating', 'includes']
# Relevant relations for the question: ['has efficiency rating']
# Triples selected for summary: [('RS%20PRO%203%20Phase%20AC%20motor', 'has efficiency rating', 'IE3 efficiency class'), ('RS%20PRO%203%20Phase%20AC%20motor', 'has efficiency rating', '78.5% at 50% load'), ('RS%20PRO%203%20Phase%20AC%20motor', 'has efficiency rating', '80.7% at 100% load'), ('RS%20PRO%203%20Phase%20AC%20motor', 'has efficiency rating', '80.8% at 75% load')]
# ============================================================
# Summary:
#  The RS PRO 3 Phase AC motor is energy-efficient and meets the IE3 efficiency class standard. Its efficiency varies depending on load: it achieves 78.5% efficiency at 50% load, 80.8% efficiency at 75% load, and 80.7% efficiency at 100% load, demonstrating consistent performance across different operating conditions.
# ============================================================
# [INFO] Graph KG_pdf_demo_01 cleared successfully.

# %%
print(summary)
# Out:
# The RS PRO 3 Phase AC motor is energy-efficient and meets the IE3 efficiency class standard. Its efficiency varies depending on load: it achieves 78.5% efficiency at 50% load, 80.8% efficiency at 75% load, and 80.7% efficiency at 100% load, demonstrating consistent performance across different operating conditions.

# %% [markdown]
# ### Scenario 2
#
# In this scenario, a procurement expert is reviewing two different industrial motors to decide if one can be used as a replacement for the other. The expert receives two PDF documents, each with the technical specifications for one of the motors. Instead of comparing details manually, the expert uses an automated system to extract a knowledge graph from each PDF. The expert then asks a specific business question, such as, “Can Motor B replace Motor A in our setup? Please focus on power rating and other key technical attributes.” The system identifies which properties in the knowledge graphs are important for this decision, retrieves the relevant facts from both motors, and uses a language model (LLM) to provide a clear, side-by-side comparison based on the business requirements. This helps the expert make an informed decision quickly and with confidence.

# %%
pdf_filename_A = "A700000008070326.pdf"  # Motor A
pdf_filename_B = "A700000006779737.pdf"  # Motor B
GRAPH_NAME_A = "KG_motor_A"
GRAPH_NAME_B = "KG_motor_B"
business_question = (
    "Can Motor B replace Motor A in our setup? "
    "Please focus on power rating and any other important technical attributes."
)

# 1. Extract triples and store in separate KGs
triples_A = extract_and_store_kg_from_pdf(
    pdf_filename=pdf_filename_A,
    GRAPH_NAME=GRAPH_NAME_A,
    KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT=KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT,
    chat_llm=chat_llm,
    dbapi=dbapi,
    to_iri=to_iri,
    to_literal=to_literal,
    hana_env=hana_env
)
triples_B = extract_and_store_kg_from_pdf(
    pdf_filename=pdf_filename_B,
    GRAPH_NAME=GRAPH_NAME_B,
    KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT=KNOWLEDGE_TRIPLE_EXTRACTION_PROMPT,
    chat_llm=chat_llm,
    dbapi=dbapi,
    to_iri=to_iri,
    to_literal=to_literal,
    hana_env=hana_env
)

# 2. Get all relations from both KGs
relations_A = get_unique_relations(GRAPH_NAME_A, dbapi, hana_env)
relations_B = get_unique_relations(GRAPH_NAME_B, dbapi, hana_env)
all_relations = list(set(relations_A) | set(relations_B))
print("All relations in both KGs:", all_relations)

# 3. Use the LLM to filter only those relations relevant for the replacement question
relevant_relations = filter_relations_by_business_question(all_relations, business_question, ask_llm_simple)
print("Relevant relations for replacement decision:", relevant_relations)

# 4. Retrieve the relevant triples from each graph
triples_A_relevant = get_triples_by_relations(GRAPH_NAME_A, relevant_relations, dbapi, hana_env)
triples_B_relevant = get_triples_by_relations(GRAPH_NAME_B, relevant_relations, dbapi, hana_env)

print("Motor A relevant triples:", triples_A_relevant)
print("Motor B relevant triples:", triples_B_relevant)

# 5. Pass both sets of triples to the LLM for a side-by-side comparison
comparison_prompt = (
    f"You are a technical expert. Here are the relevant technical facts for Motor A:\n"
    f"{triples_A_relevant}\n"
    f"And here are the relevant facts for Motor B:\n"
    f"{triples_B_relevant}\n"
    f"Based on these, answer the following business question: {business_question}\n"
    f"Give a clear, practical comparison, and say whether Motor B can reasonably replace Motor A."
)
comparison = ask_llm_simple(comparison_prompt)
print("=" * 60)
print("Replacement comparison summary:\n", comparison)
print("=" * 60)

# 6. (Optional) Clean up graphs after demo
clear_kg_graph(GRAPH_NAME_A, dbapi, hana_env)
clear_kg_graph(GRAPH_NAME_B, dbapi, hana_env)
# Out:
# [INFO] Inserting data into the graph...
# [INFO] Bulk insert of 55 triples successful.
# [INFO] Inserting data into the graph...
# [INFO] Bulk insert of 32 triples successful.
# All relations in both KGs: ['operates at frequency', 'has protection rating', 'has speed rating', 'has industry standard', 'has efficiency rating', 'has load characteristic', 'operates at voltage', 'is a', 'includes', 'is designed with', 'has insulation class', 'is equipped with', 'has temperature rating', 'has power rating']
# Relevant relations for replacement decision: ['has power rating', 'operates at frequency', 'operates at voltage', 'has speed rating', 'has efficiency rating', 'has temperature rating']
# Motor A relevant triples: [('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'operates at voltage', '690V Y'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has efficiency rating', '89.4% at 460V Δ 60Hz full load'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has power rating', '4.00 kW at 400V Δ 50Hz'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has temperature rating', '-20°C to +40°C ambient'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'operates at voltage', '460V Δ'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has efficiency rating', '89.2% at 690V Y 50Hz full load'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'operates at frequency', '50Hz'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has speed rating', '1770 RPM at 60Hz'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has power rating', '4.55 kW at 460V Δ 60Hz'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has efficiency rating', '90.0% at 460V Δ 60Hz full load'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has speed rating', '1460 RPM at 50Hz'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has power rating', '3.70 kW at 460V Δ 60Hz'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has power rating', '4.00 kW at 690V Y 50Hz'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'operates at voltage', '400V Δ'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has efficiency rating', '89.2% at 400V Δ 50Hz full load'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'operates at frequency', '60Hz'), ('1AV3112B%20SIMOTICS%20GP%20%2D%20112%20M%20%2D%20IM%20B5%20%2D%204p', 'has speed rating', '1760 RPM at 60Hz')]
# Motor B relevant triples: [('RS%20PRO%203%20Phase%20AC%20motor', 'has efficiency rating', 'IE3 efficiency class'), ('RS%20PRO%203%20Phase%20AC%20motor', 'operates at frequency', '50Hz ± 2%'), ('RS%20PRO%203%20Phase%20AC%20motor', 'has power rating', '0.75kW'), ('RS%20PRO%203%20Phase%20AC%20motor', 'operates at voltage', '400V ± 5%'), ('RS%20PRO%203%20Phase%20AC%20motor', 'has efficiency rating', '80.8% at 75% load'), ('RS%20PRO%203%20Phase%20AC%20motor', 'has temperature rating', 'temperature rise 80K'), ('RS%20PRO%203%20Phase%20AC%20motor', 'has efficiency rating', '78.5% at 50% load'), ('RS%20PRO%203%20Phase%20AC%20motor', 'has efficiency rating', '80.7% at 100% load')]
# ============================================================
# Replacement comparison summary:
#  To determine whether Motor B can replace Motor A in your setup, let's evaluate the critical factors based on the given technical data. The comparison will focus primarily on **power rating**, as it usually dictates the intended workload and application capabilities, but we will also consider other relevant technical attributes.
#
# ---
#
# ### Comparison of Motors:
#
# #### **1. Power Rating:**
# - **Motor A:**
#   - 4.00 kW at 400V Δ, 50Hz
#   - 4.00 kW at 690V Y, 50Hz
#   - 4.55 kW at 460V Δ, 60Hz
#   - 3.70 kW at 460V Δ, 60Hz (possibly lower under partial load)
#
# - **Motor B:**
#   - 0.75 kW at 400V ± 5%, 50Hz
#
# **Result:**
# Motor A has significantly higher power rating capabilities (4.55 kW vs. 0.75 kW), meaning Motor B has **far lower power output**. Motor B is unsuitable for applications requiring 4.00–4.55 kW, as it cannot handle the same workload or performance.
#
# ---
#
# #### **2. Efficiency:**
# - **Motor A:**
#   - Efficiency ranges from 89.2% to 90.0% at full load depending on voltage and frequency.
#
# - **Motor B:**
#   - IE3 efficiency class (typically decent for environmental impacts, standard in modern motors)
#   - Efficiency ranges:
#     - 80.7% at full load
#     - 80.8% at 75% load
#     - 78.5% at 50% load
#
# **Result:**
# Motor A has **higher efficiency**, especially at full load and typical working voltages. Motor B has noticeably lower efficiency performance, potentially leading to higher energy consumption costs and heat generation under load. This difference is significant if energy consumption or thermal management is a concern.
#
# ---
#
# #### **3. Voltage and Frequency Compatibility:**
# - **Motor A:** Operates at 400V Δ, 690V Y (50Hz) and 460V Δ (60Hz). Supports both 50Hz and 60Hz systems.
# - **Motor B:** Operates at 400V ± 5%, 50Hz ± 2%.
#
# **Result:**
# Voltage compatibility depends on whether your existing setup uses **400V ± 5% at 50Hz**. If you require 60Hz operation or use voltages like **460V Δ** or **690V Y**, Motor B cannot replace Motor A.
#
# ---
#
# #### **4. Speed Ratings:**
# - **Motor A:**
#   - 1460 RPM at 50Hz
#   - 1760 RPM and 1770 RPM at 60Hz
#
# - **Motor B:** No RPM specification provided.
#
# **Result:**
# Since speed ratings for Motor B are not provided, it is unknown whether it can match the rotational speed requirements of Motor A. This missing specification introduces uncertainty.
#
# ---
#
# #### **5. Temperature Ratings:**
# - **Motor A:** Ambient temperature range of -20°C to +40°C.
# - **Motor B:** Temperature rise of 80K (typically adds 80°C rise to ambient temperature; operating in much lower ambient temperatures may cause issues).
#
# **Result:**
# Motor B has narrower environmental flexibility compared to Motor A and produces more heat during operation, which may be an issue in certain setups.
#
# ---
#
# ### **Conclusion:**
# Based on the **power rating**, **efficiency**, **voltage/frequency compatibility**, and other technical attributes, **Motor B cannot reasonably replace Motor A** in your setup. The main reasons are:
#
# 1. **Power Rating Deficiency:** Motor B cannot handle the load that Motor A is designed for. Motor A offers 4.00–4.55 kW, whereas Motor B only delivers 0.75 kW. If your system relies on Motor A's higher power capacity, Motor B will not suffice.
#
# 2. **Efficiency:** Motor A provides higher efficiency at full load, reducing energy consumption and heat generation compared to Motor B.
#
# 3. **Voltage and Frequency Compatibility:** Motor B offers limited voltage and frequency ranges and lacks 60Hz compatibility, making it unsuitable for setups requiring these parameters.
#
# ### **Recommendation:**
# You should look for a motor with at least the same power rating (4.00–4.55 kW), voltage, frequency compatibility, and ideally a similar or better efficiency rating. If Motor A worked well in your setup, it would be prudent to look for a comparable or identical replacement rather than downsizing to Motor B.
# ============================================================
# [INFO] Graph KG_motor_A cleared successfully.
# [INFO] Graph KG_motor_B cleared successfully.

# %%
print(comparison)
# Out:
# To determine whether Motor B can replace Motor A in your setup, let's evaluate the critical factors based on the given technical data. The comparison will focus primarily on **power rating**, as it usually dictates the intended workload and application capabilities, but we will also consider other relevant technical attributes.
#
# ---
#
# ### Comparison of Motors:
#
# #### **1. Power Rating:**
# - **Motor A:**
#   - 4.00 kW at 400V Δ, 50Hz
#   - 4.00 kW at 690V Y, 50Hz
#   - 4.55 kW at 460V Δ, 60Hz
#   - 3.70 kW at 460V Δ, 60Hz (possibly lower under partial load)
#
# - **Motor B:**
#   - 0.75 kW at 400V ± 5%, 50Hz
#
# **Result:**
# Motor A has significantly higher power rating capabilities (4.55 kW vs. 0.75 kW), meaning Motor B has **far lower power output**. Motor B is unsuitable for applications requiring 4.00–4.55 kW, as it cannot handle the same workload or performance.
#
# ---
#
# #### **2. Efficiency:**
# - **Motor A:**
#   - Efficiency ranges from 89.2% to 90.0% at full load depending on voltage and frequency.
#
# - **Motor B:**
#   - IE3 efficiency class (typically decent for environmental impacts, standard in modern motors)
#   - Efficiency ranges:
#     - 80.7% at full load
#     - 80.8% at 75% load
#     - 78.5% at 50% load
#
# **Result:**
# Motor A has **higher efficiency**, especially at full load and typical working voltages. Motor B has noticeably lower efficiency performance, potentially leading to higher energy consumption costs and heat generation under load. This difference is significant if energy consumption or thermal management is a concern.
#
# ---
#
# #### **3. Voltage and Frequency Compatibility:**
# - **Motor A:** Operates at 400V Δ, 690V Y (50Hz) and 460V Δ (60Hz). Supports both 50Hz and 60Hz systems.
# - **Motor B:** Operates at 400V ± 5%, 50Hz ± 2%.
#
# **Result:**
# Voltage compatibility depends on whether your existing setup uses **400V ± 5% at 50Hz**. If you require 60Hz operation or use voltages like **460V Δ** or **690V Y**, Motor B cannot replace Motor A.
#
# ---
#
# #### **4. Speed Ratings:**
# - **Motor A:**
#   - 1460 RPM at 50Hz
#   - 1760 RPM and 1770 RPM at 60Hz
#
# - **Motor B:** No RPM specification provided.
#
# **Result:**
# Since speed ratings for Motor B are not provided, it is unknown whether it can match the rotational speed requirements of Motor A. This missing specification introduces uncertainty.
#
# ---
#
# #### **5. Temperature Ratings:**
# - **Motor A:** Ambient temperature range of -20°C to +40°C.
# - **Motor B:** Temperature rise of 80K (typically adds 80°C rise to ambient temperature; operating in much lower ambient temperatures may cause issues).
#
# **Result:**
# Motor B has narrower environmental flexibility compared to Motor A and produces more heat during operation, which may be an issue in certain setups.
#
# ---
#
# ### **Conclusion:**
# Based on the **power rating**, **efficiency**, **voltage/frequency compatibility**, and other technical attributes, **Motor B cannot reasonably replace Motor A** in your setup. The main reasons are:
#
# 1. **Power Rating Deficiency:** Motor B cannot handle the load that Motor A is designed for. Motor A offers 4.00–4.55 kW, whereas Motor B only delivers 0.75 kW. If your system relies on Motor A's higher power capacity, Motor B will not suffice.
#
# 2. **Efficiency:** Motor A provides higher efficiency at full load, reducing energy consumption and heat generation compared to Motor B.
#
# 3. **Voltage and Frequency Compatibility:** Motor B offers limited voltage and frequency ranges and lacks 60Hz compatibility, making it unsuitable for setups requiring these parameters.
#
# ### **Recommendation:**
# You should look for a motor with at least the same power rating (4.00–4.55 kW), voltage, frequency compatibility, and ideally a similar or better efficiency rating. If Motor A worked well in your setup, it would be prudent to look for a comparable or identical replacement rather than downsizing to Motor B.
